# %% [markdown]
# # Aspect-based SA
#
# Вспомним, какие есть подзадачи:
# - выделение упоминаний аспектов
# - классификация аспектов по категориям
# - оценка тональности по отношению к аспекту
#
# -- и всё это подозрительно напоминает наше проектное задание

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %% [markdown]
# ## preprocessing
#
# Данные уже есть в tsv формате, можем пока их просто прочитать:

# %%
# !pip install -U 'scikit-learn<0.24'
# Out:
# Requirement already satisfied: scikit-learn<0.24 in /usr/local/lib/python3.7/dist-packages (0.23.2)
# Requirement already satisfied: scipy>=0.19.1 in /usr/local/lib/python3.7/dist-packages (from scikit-learn<0.24) (1.4.1)
# Requirement already satisfied: joblib>=0.11 in /usr/local/lib/python3.7/dist-packages (from scikit-learn<0.24) (1.1.0)
# Requirement already satisfied: threadpoolctl>=2.0.0 in /usr/local/lib/python3.7/dist-packages (from scikit-learn<0.24) (3.0.0)
# Requirement already satisfied: numpy>=1.13.3 in /usr/local/lib/python3.7/dist-packages (from scikit-learn<0.24) (1.19.5)

# %%
# !pip install nltk pymorphy2
# Out:
# Requirement already satisfied: nltk in /usr/local/lib/python3.7/dist-packages (3.2.5)
# Requirement already satisfied: pymorphy2 in /usr/local/lib/python3.7/dist-packages (0.9.1)
# Requirement already satisfied: six in /usr/local/lib/python3.7/dist-packages (from nltk) (1.15.0)
# Requirement already satisfied: docopt>=0.6 in /usr/local/lib/python3.7/dist-packages (from pymorphy2) (0.6.2)
# Requirement already satisfied: dawg-python>=0.7.1 in /usr/local/lib/python3.7/dist-packages (from pymorphy2) (0.7.2)
# Requirement already satisfied: pymorphy2-dicts-ru<3.0,>=2.4 in /usr/local/lib/python3.7/dist-packages (from pymorphy2) (2.4.417127.4579844)

# %%
import pandas as pd

# %%
from nltk.tokenize import RegexpTokenizer
from pymorphy2 import MorphAnalyzer

morph = MorphAnalyzer()
token = RegexpTokenizer('\w+')

def normalize(text):
    words = [morph.parse(word)[0].normal_form for word in tokenize(text) if word]
    return words

def tokenize(text):
    return token.tokenize(text)

# %%
# !wget https://github.com/named-entity/hse-nlp/raw/master/4th_year/Project/train_aspects.txt
# !wget https://github.com/named-entity/hse-nlp/raw/master/4th_year/Project/train_reviews.txt

# %%
path = '/content/drive/MyDrive/NLProject/'
train_asp = pd.read_csv(
    path + 'train_aspects.txt', 
    delimiter='\t', 
    names=['text_id', 'category', 'mention', 'start', 'end', 'sentiment']
)
train_texts = pd.read_csv(path + 'train_reviews.txt', delimiter='\t', names=['text_id','text'])

# %%
train_asp.head(3)
# Out:
#    text_id category     mention  start  end sentiment
# 0     3976    Whole   ресторане     71   80   neutral
# 1     3976    Whole  ресторанах    198  208   neutral
# 2     3976    Whole   ресторане    256  265   neutral

# %%
train_texts.head(3)
# Out:
#    text_id                                               text
# 0     3976  День 8-го марта прошёл, можно и итоги подвести...
# 1    30808  Отмечали в этом ресторане день рождение на пер...
# 2    14031  Хочу поделиться своим впечатлением от посещени...

# %% [markdown]
# ## unsupervised aspect extraction
#
# Что можно сделать для извлечения аспектных слов, если у нас нет разметки?
# Составим частотный словарь!

# %%
train_texts['lemmas'] = [normalize(text) for text in train_texts['text']]

# %%
all_lemmas = [l for tlemmas in train_texts['lemmas'] for l in tlemmas]

# %%
import nltk
fd = nltk.FreqDist(all_lemmas)

# %%
fd.most_common(100)
# Out:
# [('и', 1443),
#  ('в', 1068),
#  ('не', 947),
#  ('быть', 682),
#  ('очень', 588),
#  ('мы', 585),
#  ('что', 572),
#  ('на', 541),
#  ('с', 521),
#  ('всё', 429),
#  ('это', 414),
#  ('ресторан', 361),
#  ('но', 357),
#  ('я', 350),
#  ('то', 226),
#  ('из', 220),
#  ('как', 219),
#  ('так', 216),
#  ('хороший', 213),
#  ('а', 210),
#  ('понравиться', 206),
#  ('к', 195),
#  ('по', 193),
#  ('блюдо', 189),
#  ('кухня', 185),
#  ('за', 184),
#  ('место', 180),
#  ('раз', 177),
#  ('обслуживание', 172),
#  ('интерьер', 169),
#  ('ещё', 166),
#  ('большой', 163),
#  ('официант', 158),
#  ('заведение', 156),
#  ('для', 155),
#  ('вкусный', 153),
#  ('меню', 150),
#  ('весь', 149),
#  ('он', 144),
#  ('есть', 139),
#  ('столик', 126),
#  ('принести', 123),
#  ('они', 123),
#  ('приятный', 121),
#  ('сказать', 120),
#  ('спасибо', 120),
#  ('друг', 117),
#  ('вкусно', 117),
#  ('день', 114),
#  ('наш', 114),
#  ('салат', 112),
#  ('у', 111),
#  ('зал', 111),
#  ('человек', 110),
#  ('еда', 110),
#  ('уютный', 109),
#  ('заказать', 107),
#  ('стол', 103),
#  ('уже', 103),
#  ('один', 103),
#  ('от', 102),
#  ('вы', 102),
#  ('минута', 101),
#  ('такой', 99),
#  ('остаться', 98),
#  ('просто', 97),
#  ('заказ', 95),
#  ('мочь', 94),
#  ('персонал', 91),
#  ('тоже', 91),
#  ('этот', 90),
#  ('время', 89),
#  ('выбор', 88),
#  ('тот', 88),
#  ('который', 87),
#  ('свой', 87),
#  ('когда', 85),
#  ('мой', 85),
#  ('только', 85),
#  ('о', 83),
#  ('цена', 83),
#  ('там', 81),
#  ('много', 81),
#  ('вечер', 80),
#  ('первый', 80),
#  ('пиво', 80),
#  ('ждать', 79),
#  ('же', 79),
#  ('общий', 79),
#  ('довольный', 77),
#  ('официантка', 77),
#  ('всегда', 75),
#  ('хотеть', 73),
#  ('порция', 73),
#  ('впечатление', 72),
#  ('при', 72),
#  ('музыка', 70),
#  ('девушка', 70),
#  ('даже', 70),
#  ('она', 70)]

# %% [markdown]
# ### задание
#
# Давайте оставим в частотном списке только существительные.
#
# Возможно, стоит также добавить биграммы (например, ADJF+NOUN, NOUN+NOUN ...)

# %%
def get_nouns(text):
  nouns = []
  for word in tokenize(text):
    if word:
      parse = morph.parse(word)[0]
      if parse.tag.POS == 'NOUN':
        nouns.append(parse.normal_form)
  return nouns

# %%
train_texts['nouns'] = [get_nouns(text) for text in train_texts['text']]

# %%
all_nouns = [l for tlemmas in train_texts['nouns'] for l in tlemmas]
fd_nouns = nltk.FreqDist(all_nouns)

# %%
fd_nouns.most_common(10)
# Out:
# [('ресторан', 361),
#  ('блюдо', 189),
#  ('кухня', 185),
#  ('место', 180),
#  ('раз', 177),
#  ('обслуживание', 172),
#  ('интерьер', 169),
#  ('официант', 158),
#  ('заведение', 156),
#  ('меню', 150)]

# %% [markdown]
# Как классифицировать полученные аспекты?
#
# Попробуем подход на основе пословных эмбеддингов:

# %%
# !pip install gensim
# Out:
# Requirement already satisfied: gensim in /usr/local/lib/python3.7/dist-packages (3.6.0)
# Requirement already satisfied: six>=1.5.0 in /usr/local/lib/python3.7/dist-packages (from gensim) (1.15.0)
# Requirement already satisfied: smart-open>=1.2.1 in /usr/local/lib/python3.7/dist-packages (from gensim) (5.2.1)
# Requirement already satisfied: scipy>=0.18.1 in /usr/local/lib/python3.7/dist-packages (from gensim) (1.4.1)
# Requirement already satisfied: numpy>=1.11.3 in /usr/local/lib/python3.7/dist-packages (from gensim) (1.19.5)

# %%
from gensim.models.keyedvectors import KeyedVectors

# %%
# !wget https://rusvectores.org/static/models/rusvectores4/ruwikiruscorpora/ruwikiruscorpora_upos_skipgram_300_2_2018.vec.gz
# Out:
# --2021-12-27 11:56:37--  https://rusvectores.org/static/models/rusvectores4/ruwikiruscorpora/ruwikiruscorpora_upos_skipgram_300_2_2018.vec.gz
# Resolving rusvectores.org (rusvectores.org)... 116.203.104.23
# Connecting to rusvectores.org (rusvectores.org)|116.203.104.23|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 394697055 (376M) [application/x-gzip]
# Saving to: ‘ruwikiruscorpora_upos_skipgram_300_2_2018.vec.gz’
#
# ruwikiruscorpora_up 100%[===================>] 376.41M   181MB/s    in 2.1s
#
# 2021-12-27 11:56:39 (181 MB/s) - ‘ruwikiruscorpora_upos_skipgram_300_2_2018.vec.gz’ saved [394697055/394697055]

# %%
# !gzip -d ruwikiruscorpora_upos_skipgram_300_2_2018.vec.gz
# Out:
# gzip: ruwikiruscorpora_upos_skipgram_300_2_2018.vec already exists; do you wish to overwrite (y or n)? n
# 	not overwritten

# %%
wv = KeyedVectors.load_word2vec_format('ruwikiruscorpora_upos_skipgram_300_2_2018.vec')

# %%
classes = ['Whole', 'Food', 'Interior', 'Service']
base_words = ['ресторан_NOUN', 'еда_NOUN', 'интерьер_NOUN', 'обслуживание_NOUN']
base_vectors = []
for c, word in zip(classes, base_words):
    base_vectors.append(wv[word])

# %% [markdown]
# Напишем функцию, выбирающую класс, базовый вектор которого ближе всего к заданному слову

# %%
import numpy as np
def get_most_similar(word):
    # YOUR CODE
    sim = wv.cosine_similarities(wv[word], base_vectors)
    return classes[np.argmax(sim)]

# %%
get_most_similar('блюдо_NOUN')
# Out:
# 'Food'

# %%
for k, v in fd_nouns.most_common(100):
  key = k + '_NOUN'
  try:
    print(key, get_most_similar(key))
  except KeyError:
    pass
# Out:
# ресторан_NOUN Whole
# блюдо_NOUN Food
# кухня_NOUN Whole
# место_NOUN Service
# обслуживание_NOUN Service
# интерьер_NOUN Interior
# официант_NOUN Whole
# заведение_NOUN Whole
# меню_NOUN Whole
# столик_NOUN Whole
# друг_NOUN Food
# день_NOUN Food
# салат_NOUN Food
# зал_NOUN Whole
# человек_NOUN Food
# еда_NOUN Food
# стол_NOUN Food
# минута_NOUN Food
# заказ_NOUN Service
# персонал_NOUN Service
# время_NOUN Food
# выбор_NOUN Service
# цена_NOUN Food
# вечер_NOUN Food
# пиво_NOUN Food
# официантка_NOUN Whole
# порция_NOUN Food
# впечатление_NOUN Interior
# музыка_NOUN Interior
# девушка_NOUN Food
# гость_NOUN Whole
# десерт_NOUN Food
# атмосфера_NOUN Interior
# отзыв_NOUN Service
# компания_NOUN Whole
# вкус_NOUN Food
# мясо_NOUN Food
# администратор_NOUN Whole
# уровень_NOUN Service
# банкет_NOUN Whole
# напиток_NOUN Food
# рождение_NOUN Whole
# вино_NOUN Food
# сервис_NOUN Service
# подруга_NOUN Whole
# повар_NOUN Food
# счёт_NOUN Service
# свадьба_NOUN Whole
# муж_NOUN Food
# год_NOUN Service
# праздник_NOUN Food
# суп_NOUN Food
# обстановка_NOUN Interior
# час_NOUN Food
# паста_NOUN Food
# народ_NOUN Food
# качество_NOUN Service
# целое_NOUN Service
# закуска_NOUN Food
# ребёнок_NOUN Food
# вход_NOUN Interior
# вид_NOUN Food
# тарелка_NOUN Food
# кафе_NOUN Whole
# соус_NOUN Food
# посетитель_NOUN Whole
# город_NOUN Whole
# этаж_NOUN Interior
# дело_NOUN Food
# стейк_NOUN Food
# алкоголь_NOUN Food
# чай_NOUN Food
# лосось_NOUN Whole
# главное_NOUN Food
# восторг_NOUN Food
# окно_NOUN Interior
# настроение_NOUN Food
# итог_NOUN Service
# конец_NOUN Food
# овощ_NOUN Food
# посещение_NOUN Service
# работа_NOUN Service
# сожаление_NOUN Food
# рыба_NOUN Food
# пара_NOUN Food
# кофе_NOUN Food
# центр_NOUN Service
# шашлык_NOUN Food
# паб_NOUN Whole
# ролл_NOUN Whole
# шеф_NOUN Whole
# цезарь_NOUN Whole
# удовольствие_NOUN Food
# ресторанчик_NOUN Whole
# пицца_NOUN Food
# сыр_NOUN Food
# креветка_NOUN Food
# дом_NOUN Whole
# взгляд_NOUN Food

# %% [markdown]
# ### ?
# Что тут можно улучшить? (можно вспомнить контекстуальные эмбеддинги)

# %% [markdown]
# ## supervised aspect extraction
#
# Теперь давайте реализуем baseline, с которым будем сравнивать проекты:
#
# - выделим все упоминания аспектов из разметки и посчитаем их частоты для каждой категории

# %%
train_asp.value_counts(subset=['mention', 'category'])
# Out:
# mention                  category
# ресторан                 Whole       100
# место                    Whole        97
# обслуживание             Service      96
# интерьер                 Interior     87
# ресторане                Whole        75
#                                     ...
# пирожными                Food          1
# пирожок к первому блюду  Food          1
# пицц                     Food          1
# пиццами                  Food          1
#  Цезарь                  Food          1
# Length: 1955, dtype: int64

# %%
s = train_asp.value_counts(subset=['mention', 'category'])

# %%
s
# Out:
# mention                  category
# ресторан                 Whole       100
# место                    Whole        97
# обслуживание             Service      96
# интерьер                 Interior     87
# ресторане                Whole        75
#                                     ...
# пирожными                Food          1
# пирожок к первому блюду  Food          1
# пицц                     Food          1
# пиццами                  Food          1
#  Цезарь                  Food          1
# Length: 1955, dtype: int64

# %%
train_counts = dict(zip(s.keys(), s.to_list()))

# %%
train_counts
# Out:
# {('ресторан', 'Whole'): 100,
#  ('место', 'Whole'): 97,
#  ('обслуживание', 'Service'): 96,
#  ('интерьер', 'Interior'): 87,
#  ('ресторане', 'Whole'): 75,
#  ('заведение', 'Whole'): 65,
#  ('Интерьер', 'Interior'): 63,
#  ('блюда', 'Food'): 58,
#  ('кухня', 'Food'): 52,
#  ('цены', 'Price'): 42,
#  ('официант', 'Service'): 39,
#  ('официантка', 'Service'): 38,
#  ('персонал', 'Service'): 37,
#  ('Кухня', 'Food'): 37,
#  ('Обслуживание', 'Service'): 35,
#  ('официанты', 'Service'): 34,
#  ('музыка', 'Interior'): 34,
#  ('порции', 'Food'): 33,
#  ('меню', 'Food'): 33,
#  ('пиво', 'Food'): 32,
#  ('еда', 'Food'): 31,
#  ('атмосфера', 'Interior'): 31,
#  ('девушка', 'Service'): 28,
#  ('ресторана', 'Whole'): 28,
#  ('заведении', 'Whole'): 24,
#  ('администратор', 'Service'): 22,
#  ('кафе', 'Whole'): 21,
#  ('горячее', 'Food'): 21,
#  ('десерт', 'Food'): 20,
#  ('заведения', 'Whole'): 19,
#  ('сервис', 'Service'): 19,
#  ('Еда', 'Food'): 19,
#  ('мясо', 'Food'): 18,
#  ('блюд', 'Food'): 18,
#  ('блюдо', 'Food'): 17,
#  ('персоналу', 'Service'): 16,
#  ('официанта', 'Service'): 16,
#  ('пива', 'Food'): 16,
#  ('Меню', 'Food'): 16,
#  ('вечер', 'Whole'): 16,
#  ('Ресторан', 'Whole'): 16,
#  ('поесть', 'Food'): 16,
#  ('Официанты', 'Service'): 16,
#  ('обстановка', 'Interior'): 15,
#  ('Порции', 'Food'): 15,
#  ('обслуживанием', 'Service'): 14,
#  ('принесли', 'Service'): 14,
#  ('кухню', 'Food'): 14,
#  ('молодой человек', 'Service'): 14,
#  ('салаты', 'Food'): 14,
#  ('ждать', 'Service'): 13,
#  ('ресторанах', 'Whole'): 13,
#  ('кухни', 'Food'): 13,
#  ('напитки', 'Food'): 13,
#  ('еды', 'Food'): 13,
#  ('зал', 'Interior'): 12,
#  ('Официант', 'Service'): 12,
#  ('еду', 'Food'): 12,
#  ('живая музыка', 'Interior'): 12,
#  ('закуски', 'Food'): 12,
#  ('суши', 'Food'): 11,
#  ('обслуживал', 'Service'): 11,
#  ('ресторанчик', 'Whole'): 11,
#  ('обслуживания', 'Service'): 11,
#  ('официантов', 'Service'): 11,
#  ('встретил', 'Service'): 11,
#  ('Сервис', 'Service'): 10,
#  ('Персонал', 'Service'): 10,
#  ('салат', 'Food'): 10,
#  ('кофе', 'Food'): 10,
#  ('встретили', 'Service'): 10,
#  ('кухней', 'Food'): 10,
#  ('еде', 'Food'): 10,
#  ('счет', 'Price'): 10,
#  ('столы', 'Interior'): 9,
#  ('интерьера', 'Interior'): 9,
#  ('ждали', 'Service'): 9,
#  ('атмосферу', 'Interior'): 9,
#  ('столик', 'Interior'): 9,
#  ('вино', 'Food'): 9,
#  ('месте', 'Whole'): 9,
#  ('пасту', 'Food'): 9,
#  ('девушки', 'Service'): 9,
#  ('вина', 'Food'): 9,
#  ('цене', 'Price'): 9,
#  ('места', 'Whole'): 9,
#  ('покушать', 'Food'): 8,
#  ('кухне', 'Food'): 8,
#  ('роллы', 'Food'): 8,
#  ('диваны', 'Interior'): 8,
#  ('чай', 'Food'): 8,
#  ('Встретили', 'Service'): 8,
#  ('официантки', 'Service'): 8,
#  ('Салаты', 'Food'): 8,
#  ('Цены', 'Price'): 7,
#  ('готовят', 'Food'): 7,
#  ('столики', 'Interior'): 7,
#  ('заведению', 'Whole'): 7,
#  ('Блюда', 'Food'): 7,
#  ('Пиво', 'Food'): 7,
#  ('обстановке', 'Interior'): 7,
#  ('встретила', 'Service'): 7,
#  ('пообедать', 'Food'): 7,
#  ('поужинать', 'Food'): 7,
#  ('кальян', 'Food'): 7,
#  ('Официантка', 'Service'): 7,
#  ('местечко', 'Whole'): 7,
#  ('ресторану', 'Whole'): 7,
#  ('персонала', 'Service'): 7,
#  ('диванчики', 'Interior'): 7,
#  ('вкус', 'Food'): 7,
#  ('десертов', 'Food'): 7,
#  ('обслуживала', 'Service'): 6,
#  ('провели время', 'Whole'): 6,
#  ('Зал', 'Interior'): 6,
#  ('Напитки', 'Food'): 6,
#  ('заведений', 'Whole'): 6,
#  ('пиццу', 'Food'): 6,
#  ('провести время', 'Whole'): 6,
#  ('официантке', 'Service'): 6,
#  ('заказ', 'Service'): 6,
#  ('официанту', 'Service'): 6,
#  ('шампанское', 'Food'): 6,
#  ('Атмосфера', 'Interior'): 6,
#  ('десерты', 'Food'): 6,
#  ('сервиса', 'Service'): 6,
#  ('шашлык', 'Food'): 6,
#  ('хлеб', 'Food'): 6,
#  ('выпить', 'Food'): 6,
#  ('Горячее', 'Food'): 6,
#  ('перекусить', 'Food'): 5,
#  ('пасты', 'Food'): 5,
#  ('администратора', 'Service'): 5,
#  ('рыба', 'Food'): 5,
#  ('атмосфере', 'Interior'): 5,
#  ('суп', 'Food'): 5,
#  ('Обстановка', 'Interior'): 5,
#  ('свечи', 'Interior'): 5,
#  ('пицца', 'Food'): 5,
#  ('стейк', 'Food'): 5,
#  ('проводили', 'Service'): 5,
#  ('ресторанов', 'Whole'): 5,
#  ('десерта', 'Food'): 5,
#  ('паб', 'Whole'): 5,
#  ('помогла', 'Service'): 5,
#  ('ценам', 'Price'): 5,
#  ('Заказ', 'Service'): 5,
#  ('цена', 'Price'): 5,
#  ('кушали', 'Food'): 5,
#  ('заказали', 'Service'): 5,
#  ('соус', 'Food'): 5,
#  ('обслуживанию', 'Service'): 5,
#  ('соуса', 'Food'): 5,
#  ('коктейли', 'Food'): 5,
#  ('свет', 'Interior'): 5,
#  ('порция', 'Food'): 5,
#  ('сервисом', 'Service'): 5,
#  ('музыку', 'Interior'): 5,
#  ('соусом', 'Food'): 5,
#  ('паста', 'Food'): 5,
#  ('мебель', 'Interior'): 5,
#  ('человек', 'Service'): 5,
#  ('работают', 'Service'): 4,
#  ('ценник', 'Price'): 4,
#  ('обслуживании', 'Service'): 4,
#  ('официантам', 'Service'): 4,
#  ('администраторы', 'Service'): 4,
#  ('салатов', 'Food'): 4,
#  ('едой', 'Food'): 4,
#  ('выбор алкоголя', 'Food'): 4,
#  ('впечатление', 'Whole'): 4,
#  ('съесть', 'Food'): 4,
#  ('съели', 'Food'): 4,
#  ('попробовать', 'Food'): 4,
#  ('официантку', 'Service'): 4,
#  ('Музыка', 'Interior'): 4,
#  ('Мясо', 'Food'): 4,
#  ('заказать', 'Service'): 4,
#  ('пивом', 'Food'): 4,
#  ('пили', 'Food'): 4,
#  ('алкоголь', 'Food'): 4,
#  ('алкоголя', 'Food'): 4,
#  ('ребята', 'Service'): 4,
#  ('поварам', 'Food'): 4,
#  ('цезарь с креветками', 'Food'): 4,
#  ('рестораны', 'Whole'): 4,
#  ('зала', 'Interior'): 4,
#  ('бизнес-ланч', 'Food'): 4,
#  ('ужин', 'Food'): 4,
#  ('горячего', 'Food'): 4,
#  ('овощи на гриле', 'Food'): 4,
#  ('овощи', 'Food'): 4,
#  ('блюдах', 'Food'): 4,
#  ('принесли меню', 'Service'): 4,
#  ('Заведение', 'Whole'): 4,
#  ('рестораном', 'Whole'): 4,
#  ('Готовят', 'Food'): 4,
#  ('морс', 'Food'): 4,
#  ('торт', 'Food'): 4,
#  ('приняла заказ', 'Service'): 4,
#  ('детская комната', 'Interior'): 4,
#  ('шеф-повару', 'Food'): 4,
#  ('приготовлено', 'Food'): 4,
#  ('скидку', 'Price'): 4,
#  ('менеджер', 'Service'): 4,
#  ('поели', 'Food'): 4,
#  ('закусок', 'Food'): 4,
#  ('посуда', 'Interior'): 4,
#  ('персоналом', 'Service'): 4,
#  ('сотрудники', 'Service'): 4,
#  ('мороженое', 'Food'): 4,
#  ('улыбаются', 'Service'): 4,
#  ('обслуживающий персонал', 'Service'): 3,
#  ('рис', 'Food'): 3,
#  ('Тан Жен', 'Whole'): 3,
#  ('Обслуживали', 'Service'): 3,
#  ('свинины', 'Food'): 3,
#  ('салями', 'Food'): 3,
#  ('скидка', 'Price'): 3,
#  ('Паста', 'Food'): 3,
#  ('салата', 'Food'): 3,
#  ('освещение', 'Interior'): 3,
#  ('рыбы', 'Food'): 3,
#  ('свинину', 'Food'): 3,
#  ('салатами', 'Food'): 3,
#  ('обслужили', 'Service'): 3,
#  ('мужчина', 'Service'): 3,
#  ('ела', 'Food'): 3,
#  ('Официантки', 'Service'): 3,
#  ('стейки', 'Food'): 3,
#  ('стены', 'Interior'): 3,
#  ('напитков', 'Food'): 3,
#  ('администратору', 'Service'): 3,
#  ('мороженого', 'Food'): 3,
#  ('японскую кухню', 'Food'): 3,
#  ('Обслуживала', 'Service'): 3,
#  ('чаевых', 'Service'): 3,
#  ('залов', 'Interior'): 3,
#  ('залы', 'Interior'): 3,
#  ('пабе', 'Whole'): 3,
#  ('Заказ приняли', 'Service'): 3,
#  ('блюдами', 'Food'): 3,
#  ('принесла меню', 'Service'): 3,
#  ('принесла', 'Service'): 3,
#  ('приборы', 'Interior'): 3,
#  ('хачапури', 'Food'): 3,
#  ('интерьере', 'Interior'): 3,
#  ('праздник', 'Whole'): 3,
#  ('гардеробщик', 'Service'): 3,
#  ('гардероб', 'Interior'): 3,
#  ('Вино', 'Food'): 3,
#  ('зале', 'Interior'): 3,
#  ('Вечер', 'Whole'): 3,
#  ('попить', 'Food'): 3,
#  ('вкуса', 'Food'): 3,
#  ('помещение', 'Interior'): 3,
#  ('Арагви', 'Whole'): 3,
#  ('водку', 'Food'): 3,
#  ('шашлыки', 'Food'): 3,
#  ('встречают', 'Service'): 3,
#  ('второй этаж', 'Interior'): 3,
#  ('выбор пива', 'Food'): 3,
#  ('выбор блюд', 'Food'): 3,
#  ('повара', 'Food'): 3,
#  ('повара', 'Service'): 3,
#  ('оформлено', 'Interior'): 3,
#  ('предложила', 'Service'): 3,
#  ('места', 'Interior'): 3,
#  ('баклажаны', 'Food'): 3,
#  ('мест', 'Whole'): 3,
#  ('отношение', 'Service'): 3,
#  ('Коктейли', 'Food'): 3,
#  ('провожают', 'Service'): 3,
#  ('местах', 'Whole'): 3,
#  ('рассказала', 'Service'): 3,
#  ('танцпол', 'Interior'): 3,
#  ('тирамису', 'Food'): 3,
#  ('супа', 'Food'): 3,
#  ('Кофе', 'Food'): 3,
#  ('салат из тунца', 'Food'): 2,
#  ('виски', 'Food'): 2,
#  ('десертам', 'Food'): 2,
#  ('работает', 'Service'): 2,
#  ('деньги', 'Price'): 2,
#  ('девушка официантка', 'Service'): 2,
#  ('вкус блюд', 'Food'): 2,
#  ('Торт', 'Food'): 2,
#  ('гарнир', 'Food'): 2,
#  ('посадили', 'Service'): 2,
#  ('Тирамису', 'Food'): 2,
#  ('Улыбаются', 'Service'): 2,
#  ('посещение', 'Whole'): 2,
#  ('обстановкой', 'Interior'): 2,
#  ('вид из окна', 'Interior'): 2,
#  ('обстановку', 'Interior'): 2,
#  ('говядина', 'Food'): 2,
#  ('Токио', 'Whole'): 2,
#  ('обслуживающему персоналу', 'Service'): 2,
#  ('помогли', 'Service'): 2,
#  ('подошли', 'Service'): 2,
#  ('поварам', 'Service'): 2,
#  ('подано', 'Service'): 2,
#  ('рассказали', 'Service'): 2,
#  ('аквариум', 'Interior'): 2,
#  ('салатом', 'Food'): 2,
#  ('повар', 'Service'): 2,
#  ('салатики', 'Food'): 2,
#  ('втором этаже', 'Interior'): 2,
#  ('отдохнули', 'Whole'): 2,
#  ('подходил', 'Service'): 2,
#  ('вкусом', 'Food'): 2,
#  ('девушке', 'Service'): 2,
#  ('расскажут', 'Service'): 2,
#  ('Суши', 'Food'): 2,
#  ('Счет', 'Price'): 2,
#  ('Счет', 'Service'): 2,
#  ('атмосферой', 'Interior'): 2,
#  ('выпили', 'Food'): 2,
#  ('вечера', 'Whole'): 2,
#  ('администрация', 'Service'): 2,
#  ('дизайн', 'Interior'): 2,
#  ('вентиляция', 'Interior'): 2,
#  ('посоветуют', 'Service'): 2,
#  ('Чебурек', 'Whole'): 2,
#  ('Чек', 'Price'): 2,
#  ('готовили', 'Food'): 2,
#  ('Шашлык', 'Food'): 2,
#  ('приготовленные', 'Food'): 2,
#  ('приготовлены', 'Food'): 2,
#  ('панакота', 'Food'): 2,
#  ('палтуса', 'Food'): 2,
#  ('готовят', 'Service'): 2,
#  ('ресторанчике', 'Whole'): 2,
#  ('белого вина', 'Food'): 2,
#  ('оформление блюд', 'Food'): 2,
#  ('блюде', 'Food'): 2,
#  ('продуктов', 'Food'): 2,
#  ('приносят', 'Service'): 2,
#  ('паба', 'Whole'): 2,
#  ('провести вечер', 'Whole'): 2,
#  ('блюд из мяса', 'Food'): 2,
#  ('оформлены', 'Food'): 2,
#  ('блины', 'Food'): 2,
#  ('проводила к столику', 'Service'): 2,
#  ('проводили к столу', 'Service'): 2,
#  ('гостями', 'Service'): 2,
#  ('ролл', 'Food'): 2,
#  ('веранде', 'Interior'): 2,
#  ('барную стойку', 'Interior'): 2,
#  ('бифштекс', 'Food'): 2,
#  ('диванчиком', 'Interior'): 2,
#  ('потанцевать', 'Interior'): 2,
#  ('говядины', 'Food'): 2,
#  ('рыбу', 'Food'): 2,
#  ('обслуживало', 'Service'): 2,
#  ('праздника', 'Whole'): 2,
#  ('официанты', 'Whole'): 2,
#  ('первый зал', 'Interior'): 2,
#  ('первом этаже', 'Interior'): 2,
#  ('оливки', 'Food'): 2,
#  ('первое блюдо', 'Food'): 2,
#  ('Цезарь', 'Food'): 2,
#  ('предложил', 'Service'): 2,
#  ('Ценник', 'Price'): 2,
#  ('ресторан', 'Service'): 2,
#  ('детское меню', 'Food'): 2,
#  ('организовала', 'Service'): 2,
#  ('предложили', 'Service'): 2,
#  ('горячие блюда', 'Food'): 2,
#  ('пасту с морепродуктами', 'Food'): 2,
#  ('бармена', 'Service'): 2,
#  ('поваров', 'Service'): 2,
#  ('Стулья', 'Interior'): 2,
#  ('музыкой', 'Interior'): 2,
#  ('Встретила', 'Service'): 2,
#  ('цен', 'Price'): 2,
#  ('Обслуживал', 'Service'): 2,
#  ('котлетки', 'Food'): 2,
#  ('Нельсон паб', 'Whole'): 2,
#  ('заказали столик', 'Service'): 2,
#  ('местом', 'Whole'): 2,
#  ('супчики', 'Food'): 2,
#  ('супы', 'Food'): 2,
#  ('Гардероб', 'Interior'): 2,
#  ('Набережную', 'Whole'): 2,
#  ('счет', 'Service'): 2,
#  ('счете', 'Price'): 2,
#  ('заказать столик', 'Service'): 2,
#  ('красиво', 'Interior'): 2,
#  ('стулья', 'Interior'): 2,
#  ('заказал', 'Service'): 2,
#  ('цену', 'Price'): 2,
#  ('стейк из тунца', 'Food'): 2,
#  ('специй', 'Food'): 2,
#  ('чебуреки', 'Food'): 2,
#  ('заведениях', 'Whole'): 2,
#  ('Блюдо', 'Food'): 2,
#  ('чая', 'Food'): 2,
#  ('стейк из лосося', 'Food'): 2,
#  ('стейк рибай', 'Food'): 2,
#  ('Обстановка в ресторане', 'Interior'): 2,
#  ('каминный зал', 'Interior'): 2,
#  ('Официанта', 'Service'): 2,
#  ('стол', 'Food'): 2,
#  ('стол', 'Interior'): 2,
#  ('заказа', 'Service'): 2,
#  ('конину', 'Food'): 2,
#  ('сыра', 'Food'): 2,
#  ('заказывали', 'Service'): 2,
#  ('сырные палочки', 'Food'): 2,
#  ('утку по-пекински', 'Food'): 2,
#  ('туалет', 'Interior'): 2,
#  ('занавесочки', 'Interior'): 2,
#  ('лосось', 'Food'): 2,
#  ('курицы', 'Food'): 2,
#  ('Заказали столик', 'Service'): 2,
#  ('ужина', 'Food'): 2,
#  ('ужинали', 'Food'): 2,
#  ('курицу', 'Food'): 2,
#  ('утку', 'Food'): 2,
#  ('Заказ принесли', 'Service'): 2,
#  ('устриц', 'Food'): 2,
#  ('лапшу с креветками', 'Food'): 2,
#  ('Ждать заказа', 'Service'): 2,
#  ('здороваются', 'Service'): 2,
#  ('люди', 'Service'): 2,
#  ('зале для курящих', 'Interior'): 2,
#  ('сырные шарики', 'Food'): 2,
#  ('телятины', 'Food'): 2,
#  ('сыром', 'Food'): 2,
#  ('креветки', 'Food'): 2,
#  ('хинкали', 'Food'): 2,
#  ('закуски к пиву', 'Food'): 2,
#  ('тарелки', 'Interior'): 2,
#  ('фрукты', 'Food'): 2,
#  ('Кухне', 'Whole'): 2,
#  ('макароны', 'Food'): 2,
#  ('маслом', 'Food'): 2,
#  ('кресла', 'Interior'): 2,
#  ('тесто', 'Food'): 2,
#  ('Десерт', 'Food'): 2,
#  ('зал для некурящих', 'Interior'): 2,
#  ('обслуживали', 'Service'): 2,
#  ('заведением', 'Whole'): 2,
#  ('концерте', 'Interior'): 2,
#  ('мяса', 'Food'): 2,
#  ('Абажур', 'Whole'): 2,
#  ('Публика', 'Interior'): 2,
#  ('наелась', 'Food'): 2,
#  ('коктели', 'Food'): 2,
#  ('Ребята', 'Service'): 2,
#  ('Ресторану', 'Whole'): 2,
#  ('напиток', 'Food'): 2,
#  ('шеф-повар', 'Service'): 2,
#  ('сервировка', 'Interior'): 2,
#  ('Салат', 'Food'): 2,
#  ('Салат "Цезарь"', 'Food'): 2,
#  ('Санторини', 'Whole'): 2,
#  ('Приносят', 'Service'): 2,
#  ('китайскую кухню', 'Food'): 2,
#  ('Свинина', 'Food'): 2,
#  ('няня', 'Service'): 2,
#  ('Соотношение цена/качество', 'Price'): 2,
#  ('2 этаже', 'Interior'): 2,
#  ('обедать', 'Food'): 2,
#  ('качество еды', 'Food'): 2,
#  ('Столик бронировали', 'Service'): 2,
#  ('Столик заказали', 'Service'): 2,
#  ('Столики', 'Interior'): 2,
#  ('Аппетит', 'Whole'): 2,
#  ('наполеон', 'Food'): 2,
#  ('уносят', 'Service'): 2,
#  ('мясе', 'Food'): 2,
#  ('Помещение', 'Interior'): 2,
#  ('Помогли', 'Service'): 2,
#  ('чек', 'Price'): 2,
#  ('чукка салат', 'Food'): 2,
#  ('зонирование', 'Interior'): 1,
#  ('карпачо', 'Food'): 1,
#  ('выбор коктейлей', 'Food'): 1,
#  ('качестве блюд', 'Food'): 1,
#  ('выбор по меню и напиткам', 'Food'): 1,
#  ('зона для некурящих', 'Interior'): 1,
#  ('зоне для курящих', 'Interior'): 1,
#  ('горячее блюдо', 'Food'): 1,
#  ('кафе-барах', 'Whole'): 1,
#  ('выполнение заказа', 'Service'): 1,
#  ('ингридиенты', 'Food'): 1,
#  ('выражением лица', 'Service'): 1,
#  ('горячие полотенца', 'Interior'): 1,
#  ('горЯчее', 'Food'): 1,
#  ('индейку', 'Food'): 1,
#  ('инегридиентов', 'Food'): 1,
#  ('выбор салатов', 'Food'): 1,
#  ('выбора горячего', 'Food'): 1,
#  ('выпито', 'Food'): 1,
#  ('интерьер зала', 'Interior'): 1,
#  ('качестве еды', 'Food'): 1,
#  ('канадский ролл', 'Food'): 1,
#  ('горячих блюд', 'Food'): 1,
#  ('камин', 'Interior'): 1,
#  ('заправкой', 'Food'): 1,
#  ('караоке', 'Interior'): 1,
#  ('каракатица', 'Food'): 1,
#  ('качество обслуживания', 'Service'): 1,
#  ('готовит', 'Food'): 1,
#  ('качество вин', 'Food'): 1,
#  ('караоке-программа', 'Interior'): 1,
#  ('готовился', 'Service'): 1,
#  ('зелень', 'Food'): 1,
#  ('готовились', 'Food'): 1,
#  ('зелень с овощами', 'Food'): 1,
#  ('кармашки с грибами и рыбой', 'Food'): 1,
#  ('земляника', 'Food'): 1,
#  ('знала меню', 'Service'): 1,
#  ('гостиная', 'Interior'): 1,
#  ('знающие меню', 'Service'): 1,
#  ('горячих блюда', 'Food'): 1,
#  ('качество блюд', 'Food'): 1,
#  ('качестве напитков', 'Food'): 1,
#  ('кафе Dolce Italy', 'Whole'): 1,
#  ('гранд-кафе 21 Верста', 'Whole'): 1,
#  ('выпивки', 'Food'): 1,
#  ('картины', 'Interior'): 1,
#  ('итальянском ресторане', 'Whole'): 1,
#  ('итоговая сумма', 'Price'): 1,
#  ('казан кабоб', 'Food'): 1,
#  ('кальянном зале', 'Interior'): 1,
#  ('картинам на стенах', 'Interior'): 1,
#  ('карта со скидкой', 'Price'): 1,
#  ('глинтвейн', 'Food'): 1,
#  ('главном зале', 'Interior'): 1,
#  ('карпаччо', 'Food'): 1,
#  ('выносят', 'Service'): 1,
#  ('карпаччо из говядины', 'Food'): 1,
#  ('выпекает', 'Food'): 1,
#  ('гарнирами', 'Food'): 1,
#  ('какаоке', 'Interior'): 1,
#  ('гардеробная', 'Interior'): 1,
#  ('гардеробщик', 'Whole'): 1,
#  ('выпечка', 'Food'): 1,
#  ('кальмары', 'Food'): 1,
#  ('кальян', 'Service'): 1,
#  ('выпечки', 'Food'): 1,
#  ('карпаччо из утиной грудки', 'Food'): 1,
#  ('выносили', 'Service'): 1,
#  ('кальянный зал', 'Interior'): 1,
#  ('интерьер ресторана', 'Interior'): 1,
#  ('выслушала', 'Service'): 1,
#  ('интерьерах', 'Interior'): 1,
#  ('интерьером', 'Interior'): 1,
#  ('карпачо сибаса', 'Food'): 1,
#  ('кафе "Кон-Коронель', 'Whole'): 1,
#  ('голос солистки', 'Interior'): 1,
#  ('выбором блюд', 'Food'): 1,
#  ('выбрать', 'Service'): 1,
#  ('вынесла', 'Service'): 1,
#  ('интерьеру', 'Interior'): 1,
#  ('интерьеры', 'Interior'): 1,
#  ('выпить пива', 'Food'): 1,
#  ('картофель фри', 'Food'): 1,
#  ('итальянская кухня', 'Food'): 1,
#  ('картофель айдахо', 'Food'): 1,
#  ('итальянские блюда', 'Food'): 1,
#  ('кальянщик', 'Service'): 1,
#  ('итальянских блюд', 'Food'): 1,
#  ('картофель "Айдахо"', 'Food'): 1,
#  ('говядину', 'Food'): 1,
#  ('итальянских ресторанах', 'Whole'): 1,
#  ('итальянской кухне', 'Food'): 1,
#  ('выбора места', 'Whole'): 1,
#  ('залам', 'Interior'): 1,
#  ('заправка', 'Food'): 1,
#  ('забронировали столик', 'Service'): 1,
#  ('диванчике', 'Interior'): 1,
#  ('диванчиках', 'Interior'): 1,
#  ('диваном', 'Interior'): 1,
#  ('жевать', 'Food'): 1,
#  ('диванах', 'Interior'): 1,
#  ('детскую комнату', 'Interior'): 1,
#  ('живой музыки', 'Interior'): 1,
#  ('живописью', 'Interior'): 1,
#  ('живую музыку', 'Interior'): 1,
#  ('жюльен', 'Food'): 1,
#  ('забирают', 'Service'): 1,
#  ('забронировал', 'Service'): 1,
#  ('забронировали стол', 'Service'): 1,
#  ('детская', 'Interior'): 1,
#  ('ждать счет', 'Service'): 1,
#  ('заведение', 'Service'): 1,
#  ('десерту', 'Food'): 1,
#  ('заведения', 'Service'): 1,
#  ('десертик', 'Food'): 1,
#  ('завернули с собой', 'Service'): 1,
#  ('десерт тирамису', 'Food'): 1,
#  ('зайти', 'Whole'): 1,
#  ('десерт семифреддо', 'Food'): 1,
#  ('десерт с бананами', 'Food'): 1,
#  ('десерт "три шоколада"', 'Food'): 1,
#  ('заказ принесла', 'Service'): 1,
#  ('депозит 5 тыс', 'Price'): 1,
#  ('заказ приносили', 'Service'): 1,
#  ('ждем', 'Service'): 1,
#  ('ждала еще минут', 'Service'): 1,
#  ('деликатесов', 'Food'): 1,
#  ('европейское меню', 'Food'): 1,
#  ('домашний куриный супчик', 'Food'): 1,
#  ('домашним морсом', 'Food'): 1,
#  ('допинга', 'Food'): 1,
#  ('дорада на тушеных овощах', 'Food'): 1,
#  ('дораду в азиатском стиле', 'Food'): 1,
#  ('дороже', 'Price'): 1,
#  ('домашние лимонады', 'Food'): 1,
#  ('домашнему морсу', 'Food'): 1,
#  ('выбор закусок', 'Food'): 1,
#  ('домашнее мороженое', 'Food'): 1,
#  ('доесть', 'Food'): 1,
#  ('доедали', 'Food'): 1,
#  ('европейские и японские блюда', 'Food'): 1,
#  ('европейскую кухню', 'Food'): 1,
#  ('ждал', 'Service'): 1,
#  ('добавляла вина', 'Service'): 1,
#  ('до заказывать', 'Service'): 1,
#  ('дисконтную карту', 'Service'): 1,
#  ('ели', 'Food'): 1,
#  ('елочка', 'Interior'): 1,
#  ('директору', 'Service'): 1,
#  ('директором', 'Service'): 1,
#  ('дизайну', 'Interior'): 1,
#  ('жаренные крылышки', 'Food'): 1,
#  ('дизайнерское решение', 'Interior'): 1,
#  ('жареного осьминога', 'Food'): 1,
#  ('жареный камамбер', 'Food'): 1,
#  ('диванчики-купе', 'Interior'): 1,
#  ('заказ приняли', 'Service'): 1,
#  ('декором', 'Interior'): 1,
#  ('запоминал', 'Service'): 1,
#  ('запеченная', 'Food'): 1,
#  ('закусывая', 'Food'): 1,
#  ('дамской комнате', 'Interior'): 1,
#  ('дали меню', 'Service'): 1,
#  ('дали', 'Whole'): 1,
#  ('дали', 'Service'): 1,
#  ('зал для курящих', 'Interior'): 1,
#  ('дала меню', 'Service'): 1,
#  ('дадут совет', 'Service'): 1,
#  ('грузинских вин', 'Food'): 1,
#  ('залах для курящих и некурящих', 'Interior'): 1,
#  ('зале для некурящих', 'Interior'): 1,
#  ('занавески', 'Interior'): 1,
#  ('грузинские танцевальный коллектив', 'Interior'): 1,
#  ('запеченной картошкой', 'Food'): 1,
#  ('закусочки', 'Food'): 1,
#  ('запеченные', 'Food'): 1,
#  ('грибами', 'Food'): 1,
#  ('грецкие орехи', 'Food'): 1,
#  ('гренки', 'Food'): 1,
#  ('запеченные суши', 'Food'): 1,
#  ('гренкам', 'Food'): 1,
#  ('запеченный сыр', 'Food'): 1,
#  ('запеченных баклажан', 'Food'): 1,
#  ('грейпфрута', 'Food'): 1,
#  ('запеченых', 'Food'): 1,
#  ('запивая', 'Food'): 1,
#  ('гребешки со спаржей', 'Food'): 1,
#  ('гребешками', 'Food'): 1,
#  ('два шоколада', 'Food'): 1,
#  ('закуску', 'Food'): 1,
#  ('заказа столика', 'Service'): 1,
#  ('девушка-официант', 'Service'): 1,
#  ('декорированные', 'Interior'): 1,
#  ('заказал столик', 'Service'): 1,
#  ('декорировании', 'Interior'): 1,
#  ('декор', 'Interior'): 1,
#  ('девченки', 'Service'): 1,
#  ('заказала', 'Service'): 1,
#  ('девушки-официантки', 'Service'): 1,
#  ('заказала столик', 'Service'): 1,
#  ('девушки официанты', 'Service'): 1,
#  ('заказан столик', 'Service'): 1,
#  ('заказанный заранее', 'Service'): 1,
#  ('девушка-певица', 'Interior'): 1,
#  ('девушка-официантка', 'Service'): 1,
#  ('девушка(официант)', 'Service'): 1,
#  ('закуски-крылья', 'Food'): 1,
#  ('заказать обычный столик', 'Service'): 1,
#  ('девушка хостесс', 'Service'): 1,
#  ('девушка хостес', 'Service'): 1,
#  ('заказываем стол', 'Service'): 1,
#  ('девушка из гардероба', 'Service'): 1,
#  ('девушка Мария', 'Service'): 1,
#  ('заказывал столик', 'Service'): 1,
#  ('девушек', 'Service'): 1,
#  ('заказывали заранее', 'Service'): 1,
#  ('заказывали столик', 'Service'): 1,
#  ('заказываю столик', 'Service'): 1,
#  ('девочку-официанта', 'Service'): 1,
#  ('двор', 'Interior'): 1,
#  ('доска с мелками', 'Interior'): 1,
#  ('блюда на мангале', 'Food'): 1,
#  ('выбор десертов', 'Food'): 1,
#  ('Невский 166', 'Whole'): 1,
#  ('Местечко', 'Whole'): 1,
#  ('Место', 'Whole'): 1,
#  ('Мидзуки', 'Whole'): 1,
#  ('Моджо', 'Whole'): 1,
#  ('Море', 'Whole'): 1,
#  ('Мороженое', 'Food'): 1,
#  ('Морс - из натуральной клюквы', 'Food'): 1,
#  ('Накормили', 'Food'): 1,
#  ('Наполеон', 'Food'): 1,
#  ('Небо', 'Whole'): 1,
#  ('Невское', 'Food'): 1,
#  ('Менеджер', 'Service'): 1,
#  ('Нельсон пабе', 'Whole'): 1,
#  ('Обслуживание', 'Whole'): 1,
#  ('Обслуживанием', 'Service'): 1,
#  ('Обслуживанию', 'Service'): 1,
#  ('Обслуживания', 'Service'): 1,
#  ('Обслуживают', 'Service'): 1,
#  ('Обслуживающий персонал', 'Service'): 1,
#  ('Общая оценка ресторану', 'Whole'): 1,
#  ('Общее мнение', 'Whole'): 1,
#  ('Овощи на гриле', 'Food'): 1,
#  ('Меню ресторана', 'Food'): 1,
#  ('Медальоны из телятины с овощами', 'Food'): 1,
#  ('Отделка', 'Interior'): 1,
#  ('Кухней', 'Food'): 1,
#  ('Качество кухни', 'Food'): 1,
#  ('Качество мяса', 'Food'): 1,
#  ('Квартиру №55', 'Whole'): 1,
#  ('Комплимент от ресторана', 'Service'): 1,
#  ('Кон-Коронель', 'Whole'): 1,
#  ('Корзину', 'Food'): 1,
#  ('Котлетки', 'Food'): 1,
#  ('Кофе капуччино', 'Food'): 1,
#  ('Кофе-десерт', 'Food'): 1,
#  ('Крапивы', 'Whole'): 1,
#  ('Кухня', 'Whole'): 1,
#  ('Медальоны из телятины', 'Food'): 1,
#  ('Лаваш', 'Food'): 1,
#  ('Лимонад', 'Food'): 1,
#  ('Макарену', 'Whole'): 1,
#  ('Малиновое "Аптекарское"', 'Food'): 1,
#  ('Мамалыгах', 'Whole'): 1,
#  ('Манго', 'Whole'): 1,
#  ('Марата', 'Whole'): 1,
#  ('Маргарита', 'Food'): 1,
#  ('Марчеллисе', 'Whole'): 1,
#  ('Медальоны из говядины с запеченным картофелем', 'Food'): 1,
#  ('Окна в пол', 'Interior'): 1,
#  ('Официант Антон', 'Service'): 1,
#  ('Карпаччо из ананаса', 'Food'): 1,
#  ('Рассказывают', 'Service'): 1,
#  ('Приносили', 'Service'): 1,
#  ('Проводила', 'Service'): 1,
#  ('Проводили', 'Service'): 1,
#  ('Прощаются', 'Service'): 1,
#  ('Работа', 'Service'): 1,
#  ('Работал', 'Service'): 1,
#  ('Рагу', 'Food'): 1,
#  ('Радио', 'Interior'): 1,
#  ('Развлекательная программа ресторана', 'Interior'): 1,
#  ('Разнообразие', 'Food'): 1,
#  ('Ребята', 'Interior'): 1,
#  ('Принес нам заказ', 'Service'): 1,
#  ('Результат вместе с чаевыми', 'Price'): 1,
#  ('Ресторан Roll & Roll', 'Whole'): 1,
#  ('Ресторанчик', 'Whole'): 1,
#  ('Рис', 'Food'): 1,
#  ('Ролл', 'Food'): 1,
#  ('Рубленные котлетки из лосося и судака с голландским соусом и белой спаржей',
#   'Food'): 1,
#  ('Руководству', 'Whole'): 1,
#  ('Рыба', 'Food'): 1,
#  ('Рыбка', 'Food'): 1,
#  ('Салат Пампелон', 'Food'): 1,
#  ('Принесли', 'Service'): 1,
#  ('Предложили', 'Service'): 1,
#  ('Официант-бармен', 'Service'): 1,
#  ('Пили', 'Food'): 1,
#  ('Официантов', 'Service'): 1,
#  ('Официанты', 'Food'): 1,
#  ('ПИВО', 'Food'): 1,
#  ('Паберти', 'Whole'): 1,
#  ('Палкине', 'Whole'): 1,
#  ('Паста с морепродуктами', 'Food'): 1,
#  ('Пастой', 'Food'): 1,
#  ('Патио на Невском', 'Whole'): 1,
#  ('Перепробовали', 'Food'): 1,
#  ('Пиво хугарден', 'Food'): 1,
#  ('Пирожные', 'Food'): 1,
#  ('Праздник', 'Whole'): 1,
#  ('Пирожных', 'Food'): 1,
#  ('Планета Суши', 'Whole'): 1,
#  ('По ценам', 'Price'): 1,
#  ('Повара', 'Food'): 1,
#  ('Подача', 'Service'): 1,
#  ('Поленте', 'Whole'): 1,
#  ('Помогли с заказом', 'Service'): 1,
#  ('Пообедали', 'Food'): 1,
#  ('Порция', 'Food'): 1,
#  ('Постное меню', 'Food'): 1,
#  ('Кафе', 'Whole'): 1,
#  ('Карпаччо', 'Food'): 1,
#  ('выбор горячих блюд', 'Food'): 1,
#  ('Впечатление осталось', 'Whole'): 1,
#  ('Береста светлое ', 'Food'): 1,
#  ('Бизнес ланч', 'Food'): 1,
#  ('Блюд', 'Food'): 1,
#  ('Бронировали стол', 'Service'): 1,
#  ('Бронировали столик', 'Service'): 1,
#  ('ВКУСНО', 'Food'): 1,
#  ('Вечером', 'Whole'): 1,
#  ('Винная карта', 'Food'): 1,
#  ('Вино красное "домашнее"', 'Food'): 1,
#  ('Восточный Экспресс', 'Whole'): 1,
#  ('Впечатления', 'Whole'): 1,
#  ('БАРЕ', 'Whole'): 1,
#  ('Впечатления от посещения', 'Whole'): 1,
#  ('Все убирали', 'Service'): 1,
#  ('Встречают', 'Service'): 1,
#  ('Второе', 'Food'): 1,
#  ('Второй этаж', 'Interior'): 1,
#  ('Выбор', 'Food'): 1,
#  ('Выбор блюд', 'Food'): 1,
#  ('Выбор еды', 'Food'): 1,
#  ('Глобуса', 'Whole'): 1,
#  ('Говядина по-дижонски', 'Food'): 1,
#  ('Базилик', 'Whole'): 1,
#  ('Атмосфера заведения', 'Interior'): 1,
#  ('Готовят', 'Service'): 1,
#  ('Администраторы', 'Service'): 1,
#  ('1450-1750р с человека', 'Price'): 1,
#  ('1ом этаже', 'Interior'): 1,
#  ('2ом этаже', 'Interior'): 1,
#  ('Da Albertone', 'Whole'): 1,
#  ('Le Glamure', 'Whole'): 1,
#  ('Legran', 'Whole'): 1,
#  ('Mon Petit Cafe', 'Whole'): 1,
#  ('Tefsi', 'Whole'): 1,
#  ('VIP зоне', 'Interior'): 1,
#  ('Администратор', 'Service'): 1,
#  ('Администрация', 'Service'): 1,
#  ('Асахи', 'Whole'): 1,
#  ('Айдахо', 'Food'): 1,
#  ('Алкоголь', 'Food'): 1,
#  ('Альмонд', 'Food'): 1,
#  ('Амадеусе', 'Whole'): 1,
#  ('Америка', 'Food'): 1,
#  ('Америка маки', 'Food'): 1,
#  ('Американо', 'Food'): 1,
#  ('Аниматоры', 'Service'): 1,
#  ('Аппетите', 'Whole'): 1,
#  ('Апрель', 'Whole'): 1,
#  ('Готовили', 'Service'): 1,
#  ('Гриль', 'Food'): 1,
#  ('Карбонара', 'Food'): 1,
#  ('Заказ принял', 'Service'): 1,
#  ('Еды', 'Food'): 1,
#  ('Ели', 'Food'): 1,
#  ('Жан-Жаке', 'Whole'): 1,
#  ('Ждал', 'Service'): 1,
#  ('Ждем', 'Service'): 1,
#  ('Жен-Жен', 'Whole'): 1,
#  ('Живая музыка', 'Interior'): 1,
#  ('ЗАВЕДЕНИЯ', 'Whole'): 1,
#  ('Заказ был выполнен', 'Service'): 1,
#  ('Заказ был принят', 'Service'): 1,
#  ('Заказала столик', 'Service'): 1,
#  ('Еду', 'Food'): 1,
#  ('Заказали', 'Service'): 1,
#  ('Заказали по купону', 'Service'): 1,
#  ('Заказывал', 'Service'): 1,
#  ('Заказывали', 'Service'): 1,
#  ('Закуски', 'Food'): 1,
#  ('Заплатили', 'Price'): 1,
#  ('Империю', 'Whole'): 1,
#  ('Итальянская музыка', 'Interior'): 1,
#  ('Капрезе', 'Food'): 1,
#  ('Караване -сарае', 'Whole'): 1,
#  ('Еду приносят', 'Service'): 1,
#  ('Европейская кухня', 'Food'): 1,
#  ('Гроссенштрассе', 'Whole'): 1,
#  ('Девушка-администратор', 'Service'): 1,
#  ('Дача', 'Whole'): 1,
#  ('Даче', 'Whole'): 1,
#  ('Дачи', 'Whole'): 1,
#  ('Дачу', 'Whole'): 1,
#  ('Два этажа', 'Interior'): 1,
#  ('Две палочки', 'Whole'): 1,
#  ('Двух палочках', 'Whole'): 1,
#  ('Девочки-официантки', 'Service'): 1,
#  ('Девушка', 'Service'): 1,
#  ('Девушка официантка', 'Service'): 1,
#  ('Девушки администраторы', 'Service'): 1,
#  ('Дугласе', 'Whole'): 1,
#  ('Девушки официантки', 'Service'): 1,
#  ('Делфим Бар', 'Whole'): 1,
#  ('Десерт Тирамису', 'Food'): 1,
#  ('Десерты', 'Food'): 1,
#  ('Диванчики', 'Interior'): 1,
#  ('Директор', 'Service'): 1,
#  ('Дитае', 'Whole'): 1,
#  ('Доесть', 'Food'): 1,
#  ('Дораду с овощами', 'Food'): 1,
#  ('Драники с беконом', 'Food'): 1,
#  ('Салат Цезарь', 'Food'): 1,
#  ('Салат грибной', 'Food'): 1,
#  ('Салат от шеф-повара с курицей', 'Food'): 1,
#  ('бронировать стол', 'Service'): 1,
#  ('бокала красного сухого вина', 'Food'): 1,
#  ('бокалах', 'Interior'): 1,
#  ('большая порция', 'Food'): 1,
#  ('большие окна', 'Interior'): 1,
#  ('большой выбор', 'Food'): 1,
#  ('большом экране', 'Interior'): 1,
#  ('борщ с копченостями', 'Food'): 1,
#  ('бронировании столика', 'Service'): 1,
#  ('бронирования столика по телефону', 'Service'): 1,
#  ('бронировать', 'Service'): 1,
#  ('бронировать столик', 'Service'): 1,
#  ('блюдо тартар с сырой рыбой и сырым яйцом', 'Food'): 1,
#  ('бронировать столы', 'Service'): 1,
#  ('бронь столика', 'Service'): 1,
#  ('буженину на гриле', 'Food'): 1,
#  ('булочки', 'Food'): 1,
#  ('бульон с мясом', 'Food'): 1,
#  ('бутылку вина', 'Food'): 1,
#  ('бытылочку вина', 'Food'): 1,
#  ('бюджетно', 'Price'): 1,
#  ('вазочки с виноградом', 'Food'): 1,
#  ('вайнштефан светлое', 'Food'): 1,
#  ('бокала коньяка', 'Food'): 1,
#  ('блюдо садж', 'Food'): 1,
#  ('васаби', 'Whole'): 1,
#  ('бизнес-ланчи', 'Food'): 1,
#  ('барменом', 'Service'): 1,
#  ('барная карта', 'Food'): 1,
#  ('барная стойка', 'Interior'): 1,
#  ('бекон на хрустящем тосте с помидором черри', 'Food'): 1,
#  ('белого сухого вина', 'Service'): 1,
#  ('бесплатно', 'Price'): 1,
#  ('бесплатной', 'Price'): 1,
#  ('бефстроганов с пюре', 'Food'): 1,
#  ('бивштексы', 'Food'): 1,
#  ('бизе со сливками и фруктами', 'Food'): 1,
#  ('билл-хук', 'Whole'): 1,
#  ('блюдам', 'Food'): 1,
#  ('блинчиками с мясом', 'Food'): 1,
#  ('блюд европейской кухни', 'Food'): 1,
#  ('блюд из меню', 'Food'): 1,
#  ('блюда восточной кухни', 'Food'): 1,
#  ('блюда и напитки выносились', 'Service'): 1,
#  ('блюда из мяса на мангале', 'Food'): 1,
#  ('блюда из осьминога', 'Food'): 1,
#  ('блюда китайской кухни', 'Food'): 1,
#  ('блюда на гриле', 'Food'): 1,
#  ('качеством приготовления', 'Food'): 1,
#  ('вареники', 'Food'): 1,
#  ('ведущая', 'Interior'): 1,
#  ('Салат с лососем', 'Food'): 1,
#  ('встреча', 'Service'): 1,
#  ('внимании', 'Service'): 1,
#  ('воды', 'Food'): 1,
#  ('вок', 'Food'): 1,
#  ('восточных салатов', 'Food'): 1,
#  ('впечатлением', 'Whole'): 1,
#  ('впечатления', 'Whole'): 1,
#  ('впечатления от паба', 'Whole'): 1,
#  ('времяпрепровождению', 'Whole'): 1,
#  ('вручила меню', 'Service'): 1,
#  ('встретит', 'Service'): 1,
#  ('встречали', 'Service'): 1,
#  ('внешний вид зала', 'Interior'): 1,
#  ('встречать', 'Service'): 1,
#  ('встречей', 'Service'): 1,
#  ('второй зал', 'Interior'): 1,
#  ('вторые блюда', 'Food'): 1,
#  ('вторыми блюдами', 'Food'): 1,
#  ('выбор', 'Food'): 1,
#  ('выбор алкогольных коктейлей', 'Food'): 1,
#  ('выбор в меню', 'Food'): 1,
#  ('выбор вин', 'Food'): 1,
#  ('выбор вина', 'Food'): 1,
#  ('внешний вид стола', 'Interior'): 1,
#  ('владелец', 'Service'): 1,
#  ('ведущей', 'Service'): 1,
#  ('вид из окон', 'Interior'): 1,
#  ('ведущий', 'Interior'): 1,
#  ('ведущих', 'Service'): 1,
#  ('вежливые', 'Service'): 1,
#  ('веранда', 'Interior'): 1,
#  ('верхнем этаже', 'Interior'): 1,
#  ('вечер прошел', 'Whole'): 1,
#  ('вечере', 'Whole'): 1,
#  ('вечером', 'Whole'): 1,
#  ('взять заказ', 'Service'): 1,
#  ('вид в зал', 'Interior'): 1,
#  ('вид на залив', 'Interior'): 1,
#  ('вкусный', 'Food'): 1,
#  ...}

# %%
train_asp['lemmas'] = [tuple(normalize(text)) for text in train_asp['mention']]

# %%
train_asp
# Out:
#       text_id category  ... sentiment                 lemmas
# 0        3976    Whole  ...   neutral            (ресторан,)
# 1        3976    Whole  ...   neutral            (ресторан,)
# 2        3976    Whole  ...   neutral            (ресторан,)
# 3        3976  Service  ...   neutral  (столик, бронировать)
# 4        3976  Service  ...  positive       (администратор,)
# ...       ...      ...  ...       ...                    ...
# 4758    16630  Service  ...  positive        (обслуживание,)
# 4759    16630     Food  ...  positive                 (еда,)
# 4760    16630  Service  ...  positive            (персонал,)
# 4761    16630    Whole  ...  positive            (ресторан,)
# 4762    16630    Whole  ...  positive               (место,)
#
# [4763 rows x 7 columns]

# %%
train_asp.value_counts(subset=['lemmas', 'category'])
# Out:
# lemmas                     category
# (ресторан,)                Whole       255
# (обслуживание,)            Service     168
# (интерьер,)                Interior    166
# (официант,)                Service     143
# (кухня,)                   Food        135
#                                       ...
# (предварительный, заказ)   Service       1
# (появляться,)              Service       1
# (появиться,)               Service       1
# (поступить,)               Service       1
# (1450, 1750р, с, человек)  Price         1
# Length: 1336, dtype: int64

# %% [markdown]
# ### ?
#
# Что тут можно улучшить?

# %%
train_asp
# Out:
#       text_id category  ... sentiment                 lemmas
# 0        3976    Whole  ...   neutral            (ресторан,)
# 1        3976    Whole  ...   neutral            (ресторан,)
# 2        3976    Whole  ...   neutral            (ресторан,)
# 3        3976  Service  ...   neutral  (столик, бронировать)
# 4        3976  Service  ...  positive       (администратор,)
# ...       ...      ...  ...       ...                    ...
# 4758    16630  Service  ...  positive        (обслуживание,)
# 4759    16630     Food  ...  positive                 (еда,)
# 4760    16630  Service  ...  positive            (персонал,)
# 4761    16630    Whole  ...  positive            (ресторан,)
# 4762    16630    Whole  ...  positive               (место,)
#
# [4763 rows x 7 columns]

# %% [markdown]
# ## sequence labelling
#
# В лекции обсуждали, что задачу разметки аспектов можно представить как задачу разметки последовательности. Что для этого нужно? Что у нас уже есть?
#
# 1. Возьмем токенизатор, который сохраняет позиции токенов (stanza)
# 2. Сведём имеющуюся разметку к формату BIO:
#   - для каждого текста возьмем список упоминаний аспектов и их позиции
#   - пройдемся по токенам, сверим их с разметкой и припишем теги

# %%
# Отмечали в этом ресторане день рождение
# O        O O    B-Whole   O    O

# %%
# !pip install stanza
# Out:
# Requirement already satisfied: stanza in /usr/local/lib/python3.7/dist-packages (1.3.0)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.7/dist-packages (from stanza) (4.62.3)
# Requirement already satisfied: requests in /usr/local/lib/python3.7/dist-packages (from stanza) (2.23.0)
# Requirement already satisfied: protobuf in /usr/local/lib/python3.7/dist-packages (from stanza) (3.17.3)
# Requirement already satisfied: torch>=1.3.0 in /usr/local/lib/python3.7/dist-packages (from stanza) (1.10.0+cu111)
# Requirement already satisfied: six in /usr/local/lib/python3.7/dist-packages (from stanza) (1.15.0)
# Requirement already satisfied: emoji in /usr/local/lib/python3.7/dist-packages (from stanza) (1.6.1)
# Requirement already satisfied: numpy in /usr/local/lib/python3.7/dist-packages (from stanza) (1.19.5)
# Requirement already satisfied: typing-extensions in /usr/local/lib/python3.7/dist-packages (from torch>=1.3.0->stanza) (3.10.0.2)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.7/dist-packages (from requests->stanza) (2021.10.8)
# Requirement already satisfied: chardet<4,>=3.0.2 in /usr/local/lib/python3.7/dist-packages (from requests->stanza) (3.0.4)
# Requirement already satisfied: idna<3,>=2.5 in /usr/local/lib/python3.7/dist-packages (from requests->stanza) (2.10)
# Requirement already satisfied: urllib3!=1.25.0,!=1.25.1,<1.26,>=1.21.1 in /usr/local/lib/python3.7/dist-packages (from requests->stanza) (1.24.3)

# %%
import stanza

# %%
stanza.download('ru')
# Out:
# Downloading https://raw.githubusercontent.com/stanfordnlp/stanza-resources/main/resources_1.3.0.json:   0%|   …
# 2021-12-27 11:59:08 INFO: Downloading default packages for language: ru (Russian)...
# 2021-12-27 11:59:10 INFO: File exists: /root/stanza_resources/ru/default.zip.
# 2021-12-27 11:59:20 INFO: Finished downloading models and saved to /root/stanza_resources.

# %%
# nlp = stanza.Pipeline('ru', processors='tokenize')
nlp = stanza.Pipeline('ru', processors='tokenize,pos')
# Out:
# 2021-12-27 11:59:20 INFO: Loading these models for language: ru (Russian):
# =========================
# | Processor | Package   |
# -------------------------
# | tokenize  | syntagrus |
# | pos       | syntagrus |
# =========================
#
# 2021-12-27 11:59:20 INFO: Use device: cpu
# 2021-12-27 11:59:20 INFO: Loading: tokenize
# 2021-12-27 11:59:20 INFO: Loading: pos
# 2021-12-27 11:59:21 INFO: Done loading processors!

# %%
# process text
nlp(train_texts['text'][0])
# Out:
# [
#   [
#     {
#       "id": 1,
#       "text": "День",
#       "upos": "NOUN",
#       "feats": "Animacy=Inan|Case=Nom|Gender=Masc|Number=Sing",
#       "start_char": 0,
#       "end_char": 4
#     },
#     {
#       "id": 2,
#       "text": "8-го",
#       "upos": "ADJ",
#       "feats": "Case=Gen|Degree=Pos|Gender=Masc|Number=Sing",
#       "start_char": 5,
#       "end_char": 9
#     },
#     {
#       "id": 3,
#       "text": "марта",
#       "upos": "NOUN",
#       "feats": "Animacy=Inan|Case=Gen|Gender=Masc|Number=Sing",
#       "start_char": 10,
#       "end_char": 15
#     },
#     {
#       "id": 4,
#       "text": "прошёл",
#       "upos": "VERB",
#       "feats": "Aspect=Perf|Gender=Masc|Mood=Ind|Number=Sing|Tense=Past|VerbForm=Fin|Voice=Act",
#       "start_char": 16,
#       "end_char": 22
#     },
#     {
#       "id": 5,
#       "text": ",",
#       "upos": "PUNCT",
#       "start_char": 22,
#       "end_char": 23
#     },
#     {
#       "id": 6,
#       "text": "можно",
#       "upos": "ADV",
#       "feats": "Degree=Pos",
#       "start_char": 24,
#       "end_char": 29
#     },
#     {
#       "id": 7,
#       "text": "и",
#       "upos": "PART",
#       "start_char": 30,
#       "end_char": 31
#     },
#     {
#       "id": 8,
#       "text": "итоги",
#       "upos": "NOUN",
#       "feats": "Animacy=Inan|Case=Acc|Gender=Masc|Number=Plur",
#       "start_char": 32,
#       "end_char": 37
#     },
#     {
#       "id": 9,
#       "text": "подвести",
#       "upos": "VERB",
#       "feats": "Aspect=Perf|VerbForm=Inf|Voice=Act",
#       "start_char": 38,
#       "end_char": 46
#     },
#     {
#       "id": 10,
#       "text": ".",
#       "upos": "PUNCT",
#       "start_char": 46,
#       "end_char": 47
#     }
#   ],
#   [
#     {
#       "id": 1,
#       "text": "Решил",
#       "upos": "VERB",
#       "feats": "Aspect=Perf|Gender=Masc|Mood=Ind|Number=Sing|Tense=Past|VerbForm=Fin|Voice=Act",
#       "start_char": 48,
#       "end_char": 53
#     },
#     {
#       "id": 2,
#       "text": "написать",
#       "upos": "VERB",
#       "feats": "Aspect=Perf|VerbForm=Inf|Voice=Act",
#       "start_char": 54,
#       "end_char": 62
#     },
#     {
#       "id": 3,
#       "text": "отзыв",
#       "upos": "NOUN",
#       "feats": "Animacy=Inan|Case=Acc|Gender=Masc|Number=Sing",
#       "start_char": 63,
#       "end_char": 68
#     },
#     {
#       "id": 4,
#       "text": "о",
#       "upos": "ADP",
#       "start_char": 69,
#       "end_char": 70
#     },
#     {
#       "id": 5,
#       "text": "ресторане",
#       "upos": "NOUN",
#       "feats": "Animacy=Inan|Case=Loc|Gender=Masc|Number=Sing",
#       "start_char": 71,
#       "end_char": 80
#     },
#     {
#       "id": 6,
#       "text": "в",
#       "upos": "ADP",
#       "start_char": 81,
#       "end_char": 82
#     },
#     {
#       "id": 7,
#       "text": "котором",
#       "upos": "PRON",
#       "feats": "Case=Loc",
#       "start_char": 83,
#       "end_char": 90
#     },
#     {
#       "id": 8,
#       "text": "отметили",
#       "upos": "VERB",
#       "feats": "Aspect=Perf|Mood=Ind|Number=Plur|Tense=Past|VerbForm=Fin|Voice=Act",
#       "start_char": 91,
#       "end_char": 99
#     },
#     {
#       "id": 9,
#       "text": "прекрасный",
#       "upos": "ADJ",
#       "feats": "Case=Acc|Degree=Pos|Gender=Masc|Number=Sing",
#       "start_char": 100,
#       "end_char": 110
#     },
#     {
#       "id": 10,
#       "text": "весений",
#       "upos": "NOUN",
#       "feats": "Animacy=Inan|Case=Gen|Gender=Neut|Number=Plur",
#       "start_char": 111,
#       "end_char": 118
#     },
#     {
#       "id": 11,
#       "text": "праздник",
#       "upos": "NOUN",
#       "feats": "Animacy=Inan|Case=Nom|Gender=Masc|Number=Sing",
#       "start_char": 119,
#       "end_char": 127
#     },
#     {
#       "id": 12,
#       "text": ",",
#       "upos": "PUNCT",
#       "start_char": 127,
#       "end_char": 128
#     },
#     {
#       "id": 13,
#       "text": "прочитал",
#       "upos": "VERB",
#       "feats": "Aspect=Perf|Gender=Masc|Mood=Ind|Number=Sing|Tense=Past|VerbForm=Fin|Voice=Act",
#       "start_char": 129,
#       "end_char": 137
#     },
#     {
#       "id": 14,
#       "text": "отзывы",
#       "upos": "NOUN",
#       "feats": "Animacy=Inan|Case=Acc|Gender=Masc|Number=Plur",
#       "start_char": 138,
#       "end_char": 144
#     },
#     {
#       "id": 15,
#       "text": "edik077",
#       "upos": "PROPN",
#       "feats": "Foreign=Yes",
#       "start_char": 145,
#       "end_char": 152
#     },
#     {
#       "id": 16,
#       "text": "и",
#       "upos": "CCONJ",
#       "start_char": 153,
#       "end_char": 154
#     },
#     {
#       "id": 17,
#       "text": "Rules77777и",
#       "upos": "PROPN",
#       "feats": "Foreign=Yes",
#       "start_char": 155,
#       "end_char": 166
#     },
#     {
#       "id": 18,
#       "text": "понял",
#       "upos": "VERB",
#       "feats": "Aspect=Perf|Gender=Masc|Mood=Ind|Number=Sing|Tense=Past|VerbForm=Fin|Voice=Act",
#       "start_char": 167,
#       "end_char": 172
#     },
#     {
#       "id": 19,
#       "text": "что",
#       "upos": "SCONJ",
#       "start_char": 173,
#       "end_char": 176
#     },
#     {
#       "id": 20,
#       "text": "либо",
#       "upos": "CCONJ",
#       "start_char": 177,
#       "end_char": 181
#     },
#     {
#       "id": 21,
#       "text": "мы",
#       "upos": "PRON",
#       "feats": "Case=Nom|Number=Plur|Person=1",
#       "start_char": 182,
#       "end_char": 184
#     },
#     {
#       "id": 22,
#       "text": "были",
#       "upos": "AUX",
#       "feats": "Aspect=Imp|Mood=Ind|Number=Plur|Tense=Past|VerbForm=Fin|Voice=Act",
#       "start_char": 185,
#       "end_char": 189
#     },
#     {
#       "id": 23,
#       "text": "вразных",
#       "upos": "ADJ",
#       "feats": "Case=Gen|Degree=Pos|Number=Plur",
#       "start_char": 190,
#       "end_char": 197
#     },
#     {
#       "id": 24,
#       "text": "ресторанах",
#       "upos": "NOUN",
#       "feats": "Animacy=Inan|Case=Loc|Gender=Masc|Number=Plur",
#       "start_char": 198,
#       "end_char": 208
#     },
#     {
#       "id": 25,
#       "text": ",",
#       "upos": "PUNCT",
#       "start_char": 208,
#       "end_char": 209
#     },
#     {
#       "id": 26,
#       "text": "либо",
#       "upos": "CCONJ",
#       "start_char": 210,
#       "end_char": 214
#     },
#     {
#       "id": 27,
#       "text": "у",
#       "upos": "ADP",
#       "start_char": 215,
#       "end_char": 216
#     },
#     {
#       "id": 28,
#       "text": "ребят",
#       "upos": "NOUN",
#       "feats": "Animacy=Anim|Case=Gen|Gender=Neut|Number=Plur",
#       "start_char": 217,
#       "end_char": 222
#     },
#     {
#       "id": 29,
#       "text": "что-то",
#       "upos": "PRON",
#       "feats": "Case=Nom",
#       "start_char": 223,
#       "end_char": 229
#     },
#     {
#       "id": 30,
#       "text": "незаладилось",
#       "upos": "VERB",
#       "feats": "Aspect=Imp|Gender=Neut|Mood=Ind|Number=Sing|Tense=Past|VerbForm=Fin|Voice=Mid",
#       "start_char": 230,
#       "end_char": 242
#     },
#     {
#       "id": 31,
#       "text": ".",
#       "upos": "PUNCT",
#       "start_char": 242,
#       "end_char": 243
#     }
#   ],
#   [
#     {
#       "id": 1,
#       "text": "Но",
#       "upos": "CCONJ",
#       "start_char": 244,
#       "end_char": 246
#     },
#     {
#       "id": 2,
#       "text": "теперь",
#       "upos": "ADV",
#       "feats": "Degree=Pos",
#       "start_char": 247,
#       "end_char": 253
#     },
#     {
#       "id": 3,
#       "text": "о",
#       "upos": "ADP",
#       "start_char": 254,
#       "end_char": 255
#     },
#     {
#       "id": 4,
#       "text": "ресторане",
#       "upos": "NOUN",
#       "feats": "Animacy=Inan|Case=Loc|Gender=Masc|Number=Sing",
#       "start_char": 256,
#       "end_char": 265
#     },
#     {
#       "id": 5,
#       "text": ".",
#       "upos": "PUNCT",
#       "start_char": 265,
#       "end_char": 266
#     }
#   ],
#   [
#     {
#       "id": 1,
#       "text": "Столик",
#       "upos": "NOUN",
#       "feats": "Animacy=Inan|Case=Acc|Gender=Masc|Number=Sing",
#       "start_char": 267,
#       "end_char": 273
#     },
#     {
#       "id": 2,
#       "text": "бронировали",
#       "upos": "VERB",
#       "feats": "Aspect=Imp|Mood=Ind|Number=Plur|Tense=Past|VerbForm=Fin|Voice=Act",
#       "start_char": 274,
#       "end_char": 285
#     },
#     {
#       "id": 3,
#       "text": "заранее",
#       "upos": "ADV",
#       "feats": "Degree=Pos",
#       "start_char": 286,
#       "end_char": 293
#     },
#     {
#       "id": 4,
#       "text": "и",
#       "upos": "CCONJ",
#       "start_char": 294,
#       "end_char": 295
#     },
#     {
#       "id": 5,
#       "text": "сделали",
#       "upos": "VERB",
#       "feats": "Aspect=Perf|Mood=Ind|Number=Plur|Tense=Past|VerbForm=Fin|Voice=Act",
#       "start_char": 296,
#       "end_char": 303
#     },
#     {
#       "id": 6,
#       "text": "так",
#       "upos": "ADV",
#       "feats": "Degree=Pos",
#       "start_char": 304,
#       "end_char": 307
#     },
#     {
#       "id": 7,
#       "text": "как",
#       "upos": "SCONJ",
#       "start_char": 308,
#       "end_char": 311
#     },
#     {
#       "id": 8,
#       "text": "предложил",
#       "upos": "VERB",
#       "feats": "Aspect=Perf|Gender=Masc|Mood=Ind|Number=Sing|Tense=Past|VerbForm=Fin|Voice=Act",
#       "start_char": 312,
#       "end_char": 321
#     },
#     {
#       "id": 9,
#       "text": "администратор",
#       "upos": "NOUN",
#       "feats": "Animacy=Anim|Case=Nom|Gender=Masc|Number=Sing",
#       "start_char": 322,
#       "end_char": 335
#     },
#     {
#       "id": 10,
#       "text": "т.е.",
#       "upos": "PUNCT",
#       "start_char": 336,
#       "end_char": 340
#     },
#     {
#       "id": 11,
#       "text": "сделали",
#       "upos": "VERB",
#       "feats": "Aspect=Perf|Mood=Ind|Number=Plur|Tense=Past|VerbForm=Fin|Voice=Act",
#       "start_char": 341,
#       "end_char": 348
#     },
#     {
#       "id": 12,
#       "text": "предварительный",
#       "upos": "ADJ",
#       "feats": "Animacy=Inan|Case=Acc|Degree=Pos|Gender=Masc|Number=Sing",
#       "start_char": 349,
#       "end_char": 364
#     },
#     {
#       "id": 13,
#       "text": "заказ",
#       "upos": "NOUN",
#       "feats": "Animacy=Inan|Case=Acc|Gender=Masc|Number=Sing",
#       "start_char": 365,
#       "end_char": 370
#     },
#     {
#       "id": 14,
#       "text": ",",
#       "upos": "PUNCT",
#       "start_char": 370,
#       "end_char": 371
#     },
#     {
#       "id": 15,
#       "text": "когда",
#       "upos": "SCONJ",
#       "start_char": 372,
#       "end_char": 377
#     },
#     {
#       "id": 16,
#       "text": "придя",
#       "upos": "VERB",
#       "feats": "Aspect=Perf|Tense=Past|VerbForm=Conv|Voice=Act",
#       "start_char": 378,
#       "end_char": 383
#     },
#     {
#       "id": 17,
#       "text": "увидели",
#       "upos": "VERB",
#       "feats": "Aspect=Perf|Mood=Ind|Number=Plur|Tense=Past|VerbForm=Fin|Voice=Act",
#       "start_char": 384,
#       "end_char": 391
#     },
#     {
#       "id": 18,
#       "text": "полностью",
#       "upos": "ADV",
#       "feats": "Degree=Pos",
#       "start_char": 392,
#       "end_char": 401
#     },
#     {
#       "id": 19,
#       "text": "заполненый",
#       "upos": "VERB",
#       "feats": "Animacy=Inan|Aspect=Perf|Case=Acc|Gender=Masc|Number=Sing|Tense=Past|VerbForm=Part|Voice=Pass",
#       "start_char": 402,
#       "end_char": 412
#     },
#     {
#       "id": 20,
#       "text": "ресторан",
#       "upos": "NOUN",
#       "feats": "Animacy=Inan|Case=Acc|Gender=Masc|Number=Sing",
#       "start_char": 413,
#       "end_char": 421
#     },
#     {
#       "id": 21,
#       "text": "поняли",
#       "upos": "VERB",
#       "feats": "Aspect=Perf|Mood=Ind|Number=Plur|Tense=Past|VerbForm=Fin|Voice=Act",
#       "start_char": 422,
#       "end_char": 428
#     },
#     {
#       "id": 22,
#       "text": "что",
#       "upos": "SCONJ",
#       "start_char": 429,
#       "end_char": 432
#     },
#     {
#       "id": 23,
#       "text": "совет",
#       "upos": "NOUN",
#       "feats": "Animacy=Inan|Case=Nom|Gender=Masc|Number=Sing",
#       "start_char": 433,
#       "end_char": 438
#     },
#     {
#       "id": 24,
#       "text": "нам",
#       "upos": "PRON",
#       "feats": "Case=Dat|Number=Plur|Person=1",
#       "start_char": 439,
#       "end_char": 442
#     },
#     {
#       "id": 25,
#       "text": "дали",
#       "upos": "VERB",
#       "feats": "Aspect=Perf|Mood=Ind|Number=Plur|Tense=Past|VerbForm=Fin|Voice=Act",
#       "start_char": 443,
#       "end_char": 447
#     },
#     {
#       "id": 26,
#       "text": "действительно",
#       "upos": "ADV",
#       "feats": "Degree=Pos",
#       "start_char": 448,
#       "end_char": 461
#     },
#     {
#       "id": 27,
#       "text": "правильный",
#       "upos": "ADJ",
#       "feats": "Animacy=Inan|Case=Acc|Degree=Pos|Gender=Masc|Number=Sing",
#       "start_char": 462,
#       "end_char": 472
#     },
#     {
#       "id": 28,
#       "text": ",",
#       "upos": "PUNCT",
#       "start_char": 472,
#       "end_char": 473
#     },
#     {
#       "id": 29,
#       "text": "в",
#       "upos": "ADP",
#       "start_char": 474,
#       "end_char": 475
#     },
#     {
#       "id": 30,
#       "text": "ресторане",
#       "upos": "NOUN",
#       "feats": "Animacy=Inan|Case=Loc|Gender=Masc|Number=Sing",
#       "start_char": 476,
#       "end_char": 485
#     },
#     {
#       "id": 31,
#       "text": "было",
#       "upos": "VERB",
#       "feats": "Aspect=Imp|Gender=Neut|Mood=Ind|Number=Sing|Tense=Past|VerbForm=Fin|Voice=Act",
#       "start_char": 486,
#       "end_char": 490
#     },
#     {
#       "id": 32,
#       "text": "человек",
#       "upos": "NOUN",
#       "feats": "Animacy=Anim|Case=Nom|Gender=Masc|Number=Plur",
#       "start_char": 491,
#       "end_char": 498
#     },
#     {
#       "id": 33,
#       "text": "70",
#       "upos": "NUM",
#       "start_char": 499,
#       "end_char": 501
#     },
#     {
#       "id": 34,
#       "text": "-",
#       "upos": "PUNCT",
#       "start_char": 501,
#       "end_char": 502
#     },
#     {
#       "id": 35,
#       "text": "80",
#       "upos": "NUM",
#       "start_char": 502,
#       "end_char": 504
#     },
#     {
#       "id": 36,
#       "text": ",",
#       "upos": "PUNCT",
#       "start_char": 504,
#       "end_char": 505
#     },
#     {
#       "id": 37,
#       "text": "тут",
#       "upos": "ADV",
#       "feats": "Degree=Pos",
#       "start_char": 506,
#       "end_char": 509
#     },
#     {
#       "id": 38,
#       "text": "действительно",
#       "upos": "ADV",
#       "feats": "Degree=Pos",
#       "start_char": 510,
#       "end_char": 523
#     },
#     {
#       "id": 39,
#       "text": "горячее",
#       "upos": "ADJ",
#       "feats": "Case=Acc|Degree=Pos|Gender=Neut|Number=Sing",
#       "start_char": 524,
#       "end_char": 531
#     },
#     {
#       "id": 40,
#       "text": "блюдо",
#       "upos": "NOUN",
#       "feats": "Animacy=Inan|Case=Acc|Gender=Neut|Number=Sing",
#       "start_char": 532,
#       "end_char": 537
#     },
#     {
#       "id": 41,
#       "text": "можно",
#       "upos": "ADV",
#       "feats": "Degree=Pos",
#       "start_char": 538,
#       "end_char": 543
#     },
#     {
#       "id": 42,
#       "text": "ждать",
#       "upos": "VERB",
#       "feats": "Aspect=Imp|VerbForm=Inf|Voice=Act",
#       "start_char": 544,
#       "end_char": 549
#     },
#     {
#       "id": 43,
#       "text": "весьма",
#       "upos": "ADV",
#       "feats": "Degree=Pos",
#       "start_char": 550,
#       "end_char": 556
#     },
#     {
#       "id": 44,
#       "text": "долго",
#       "upos": "ADV",
#       "feats": "Degree=Pos",
#       "start_char": 557,
#       "end_char": 562
#     },
#     {
#       "id": 45,
#       "text": ".",
#       "upos": "PUNCT",
#       "start_char": 562,
#       "end_char": 563
#     }
#   ],
#   [
#     {
#       "id": 1,
#       "text": "Меню",
#       "upos": "NOUN",
#       "feats": "Animacy=Inan|Case=Nom|Gender=Neut|Number=Sing",
#       "start_char": 564,
#       "end_char": 568
#     },
#     {
#       "id": 2,
#       "text": "достаточно",
#       "upos": "ADV",
#       "feats": "Degree=Pos",
#       "start_char": 569,
#       "end_char": 579
#     },
#     {
#       "id": 3,
#       "text": "разнообразное",
#       "upos": "ADJ",
#       "feats": "Case=Nom|Degree=Pos|Gender=Neut|Number=Sing",
#       "start_char": 580,
#       "end_char": 593
#     },
#     {
#       "id": 4,
#       "text": "и",
#       "upos": "CCONJ",
#       "start_char": 594,
#       "end_char": 595
#     },
#     {
#       "id": 5,
#       "text": "весьма",
#       "upos": "ADV",
#       "feats": "Degree=Pos",
#       "start_char": 596,
#       "end_char": 602
#     },
#     {
#       "id": 6,
#       "text": "вкусное",
#       "upos": "ADJ",
#       "feats": "Case=Nom|Degree=Pos|Gender=Neut|Number=Sing",
#       "start_char": 603,
#       "end_char": 610
#     },
#     {
#       "id": 7,
#       "text": ",",
#       "upos": "PUNCT",
#       "start_char": 610,
#       "end_char": 611
#     },
#     {
#       "id": 8,
#       "text": "мне",
#       "upos": "PRON",
#       "feats": "Case=Dat|Number=Sing|Person=1",
#       "start_char": 612,
#       "end_char": 615
#     },
#     {
#       "id": 9,
#       "text": "и",
#       "upos": "CCONJ",
#       "start_char": 616,
#       "end_char": 617
#     },
#     {
#       "id": 10,
#       "text": "моим",
#       "upos": "DET",
#       "feats": "Case=Dat|Number=Plur",
#       "start_char": 618,
#       "end_char": 622
#     },
#     {
#       "id": 11,
#       "text": "друзьям",
#       "upos": "NOUN",
#       "feats": "Animacy=Anim|Case=Dat|Gender=Masc|Number=Plur",
#       "start_char": 623,
#       "end_char": 630
#     },
#     {
#       "id": 12,
#       "text": "понравилось",
#       "upos": "VERB",
#       "feats": "Aspect=Perf|Gender=Neut|Mood=Ind|Number=Sing|Tense=Past|VerbForm=Fin|Voice=Mid",
#       "start_char": 631,
#       "end_char": 642
#     },
#     {
#       "id": 13,
#       "text": "всё",
#       "upos": "PRON",
#       "feats": "Animacy=Inan|Case=Nom|Gender=Neut|Number=Sing",
#       "start_char": 643,
#       "end_char": 646
#     },
#     {
#       "id": 14,
#       "text": "что",
#       "upos": "PRON",
#       "feats": "Case=Acc",
#       "start_char": 647,
#       "end_char": 650
#     },
#     {
#       "id": 15,
#       "text": "нам",
#       "upos": "PRON",
#       "feats": "Case=Dat|Number=Plur|Person=1",
#       "start_char": 651,
#       "end_char": 654
#     },
#     {
#       "id": 16,
#       "text": "принесли",
#       "upos": "VERB",
#       "feats": "Aspect=Perf|Mood=Ind|Number=Plur|Tense=Past|VerbForm=Fin|Voice=Act",
#       "start_char": 655,
#       "end_char": 663
#     },
#     {
#       "id": 17,
#       "text": ",",
#       "upos": "PUNCT",
#       "start_char": 663,
#       "end_char": 664
#     },
#     {
#       "id": 18,
#       "text": "а",
#       "upos": "CCONJ",
#       "start_char": 665,
#       "end_char": 666
#     },
#     {
#       "id": 19,
#       "text": "принесли",
#       "upos": "VERB",
#       "feats": "Aspect=Perf|Mood=Ind|Number=Plur|Tense=Past|VerbForm=Fin|Voice=Act",
#       "start_char": 667,
#       "end_char": 675
#     },
#     {
#       "id": 20,
#       "text": "нам",
#       "upos": "PRON",
#       "feats": "Case=Dat|Number=Plur|Person=1",
#       "start_char": 676,
#       "end_char": 679
#     },
#     {
#       "id": 21,
#       "text": "немало",
#       "upos": "ADV",
#       "feats": "Degree=Pos",
#       "start_char": 680,
#       "end_char": 686
#     },
#     {
#       "id": 22,
#       "text": ".",
#       "upos": "PUNCT",
#       "start_char": 686,
#       "end_char": 687
#     }
#   ],
#   [
#     {
#       "id": 1,
#       "text": "Обслуживание",
#       "upos": "NOUN",
#       "feats": "Animacy=Inan|Case=Nom|Gender=Neut|Number=Sing",
#       "start_char": 688,
#       "end_char": 700
#     },
#     {
#       "id": 2,
#       "text": "может",
#       "upos": "VERB",
#       "feats": "Aspect=Imp|Mood=Ind|Number=Sing|Person=3|Tense=Pres|VerbForm=Fin|Voice=Act",
#       "start_char": 701,
#       "end_char": 706
#     },
#     {
#       "id": 3,
#       "text": "и",
#       "upos": "PART",
#       "start_char": 707,
#       "end_char": 708
#     },
#     {
#       "id": 4,
#       "text": "не",
#       "upos": "PART",
#       "start_char": 709,
#       "end_char": 711
#     },
#     {
#       "id": 5,
#       "text": "самое",
#       "upos": "ADJ",
#       "feats": "Case=Nom|Degree=Pos|Gender=Neut|Number=Sing",
#       "start_char": 712,
#       "end_char": 717
#     },
#     {
#       "id": 6,
#       "text": "лучьшее",
#       "upos": "ADJ",
#       "feats": "Case=Nom|Degree=Pos|Gender=Neut|Number=Sing",
#       "start_char": 718,
#       "end_char": 725
#     },
#     {
#       "id": 7,
#       "text": "в",
#       "upos": "ADP",
#       "start_char": 726,
#       "end_char": 727
#     },
#     {
#       "id": 8,
#       "text": "городе",
#       "upos": "NOUN",
#       "feats": "Animacy=Inan|Case=Loc|Gender=Masc|Number=Sing",
#       "start_char": 728,
#       "end_char": 734
#     },
#     {
#       "id": 9,
#       "text": ",",
#       "upos": "PUNCT",
#       "start_char": 734,
#       "end_char": 735
#     },
#     {
#       "id": 10,
#       "text": "но",
#       "upos": "CCONJ",
#       "start_char": 736,
#       "end_char": 738
#     },
#     {
#       "id": 11,
#       "text": "официанты",
#       "upos": "NOUN",
#       "feats": "Animacy=Anim|Case=Nom|Gender=Masc|Number=Plur",
#       "start_char": 739,
#       "end_char": 748
#     },
#     {
#       "id": 12,
#       "text": "делали",
#       "upos": "VERB",
#       "feats": "Aspect=Imp|Mood=Ind|Number=Plur|Tense=Past|VerbForm=Fin|Voice=Act",
#       "start_char": 749,
#       "end_char": 755
#     },
#     {
#       "id": 13,
#       "text": "всё",
#       "upos": "PRON",
#       "feats": "Animacy=Inan|Case=Acc|Gender=Neut|Number=Sing",
#       "start_char": 756,
#       "end_char": 759
#     },
#     {
#       "id": 14,
#       "text": "что",
#       "upos": "PRON",
#       "feats": "Case=Acc",
#       "start_char": 760,
#       "end_char": 763
#     },
#     {
#       "id": 15,
#       "text": "нужно",
#       "upos": "ADJ",
#       "feats": "Degree=Pos|Gender=Neut|Number=Sing|Variant=Short",
#       "start_char": 764,
#       "end_char": 769
#     },
#     {
#       "id": 16,
#       "text": ".",
#       "upos": "PUNCT",
#       "start_char": 769,
#       "end_char": 770
#     }
#   ],
#   [
#     {
#       "id": 1,
#       "text": "Должен",
#       "upos": "ADJ",
#       "feats": "Degree=Pos|Gender=Masc|Number=Sing|Variant=Short",
#       "start_char": 771,
#       "end_char": 777
#     },
#     {
#       "id": 2,
#       "text": "сказать",
#       "upos": "VERB",
#       "feats": "Aspect=Perf|VerbForm=Inf|Voice=Act",
#       "start_char": 778,
#       "end_char": 785
#     },
#     {
#       "id": 3,
#       "text": "что",
#       "upos": "SCONJ",
#       "start_char": 786,
#       "end_char": 789
#     },
#     {
#       "id": 4,
#       "text": "ждать",
#       "upos": "VERB",
#       "feats": "Aspect=Imp|VerbForm=Inf|Voice=Act",
#       "start_char": 790,
#       "end_char": 795
#     },
#     {
#       "id": 5,
#       "text": "нам",
#       "upos": "PRON",
#       "feats": "Case=Dat|Number=Plur|Person=1",
#       "start_char": 796,
#       "end_char": 799
#     },
#     {
#       "id": 6,
#       "text": "всёравно",
#       "upos": "ADV",
#       "feats": "Degree=Pos",
#       "start_char": 800,
#       "end_char": 808
#     },
#     {
#       "id": 7,
#       "text": "пришлось",
#       "upos": "VERB",
#       "feats": "Aspect=Perf|Gender=Neut|Mood=Ind|Number=Sing|Tense=Past|VerbForm=Fin|Voice=Mid",
#       "start_char": 809,
#       "end_char": 817
#     },
#     {
#       "id": 8,
#       "text": ",",
#       "upos": "PUNCT",
#       "start_char": 817,
#       "end_char": 818
#     },
#     {
#       "id": 9,
#       "text": "не",
#       "upos": "PART",
#       "start_char": 819,
#       "end_char": 821
#     },
#     {
#       "id": 10,
#       "text": "очень",
#       "upos": "ADV",
#       "feats": "Degree=Pos",
#       "start_char": 822,
#       "end_char": 827
#     },
#     {
#       "id": 11,
#       "text": "долго",
#       "upos": "ADV",
#       "feats": "Degree=Pos",
#       "start_char": 828,
#       "end_char": 833
#     },
#     {
#       "id": 12,
#       "text": "конечно",
#       "upos": "ADV",
#       "feats": "Degree=Pos",
#       "start_char": 834,
#       "end_char": 841
#     },
#     {
#       "id": 13,
#       "text": ",",
#       "upos": "PUNCT",
#       "start_char": 841,
#       "end_char": 842
#     },
#     {
#       "id": 14,
#       "text": "но",
#       "upos": "CCONJ",
#       "start_char": 843,
#       "end_char": 845
#     },
#     {
#       "id": 15,
#       "text": "всё-же",
#       "upos": "ADV",
#       "feats": "Degree=Pos",
#       "start_char": 846,
#       "end_char": 852
#     },
#     {
#       "id": 16,
#       "text": ".",
#       "upos": "PUNCT",
#       "start_char": 852,
#       "end_char": 853
#     }
#   ],
#   [
#     {
#       "id": 1,
#       "text": "Интерьер",
#       "upos": "NOUN",
#       "feats": "Animacy=Inan|Case=Nom|Gender=Masc|Number=Sing",
#       "start_char": 854,
#       "end_char": 862
#     },
#     {
#       "id": 2,
#       "text": "хороший",
#       "upos": "ADJ",
#       "feats": "Case=Nom|Degree=Pos|Gender=Masc|Number=Sing",
#       "start_char": 863,
#       "end_char": 870
#     },
#     {
#       "id": 3,
#       "text": ",",
#       "upos": "PUNCT",
#       "start_char": 870,
#       "end_char": 871
#     },
#     {
#       "id": 4,
#       "text": "удобные",
#       "upos": "ADJ",
#       "feats": "Case=Nom|Degree=Pos|Number=Plur",
#       "start_char": 872,
#       "end_char": 879
#     },
#     {
#       "id": 5,
#       "text": "диваны",
#       "upos": "NOUN",
#       "feats": "Animacy=Inan|Case=Nom|Gender=Masc|Number=Plur",
#       "start_char": 880,
#       "end_char": 886
#     },
#     {
#       "id": 6,
#       "text": ".",
#       "upos": "PUNCT",
#       "start_char": 886,
#       "end_char": 887
#     }
#   ],
#   [
#     {
#       "id": 1,
#       "text": "Очень",
#       "upos": "ADV",
#       "feats": "Degree=Pos",
#       "start_char": 887,
#       "end_char": 892
#     },
#     {
#       "id": 2,
#       "text": "хорошая",
#       "upos": "ADJ",
#       "feats": "Case=Nom|Degree=Pos|Gender=Fem|Number=Sing",
#       "start_char": 893,
#       "end_char": 900
#     },
#     {
#       "id": 3,
#       "text": "музыкальная",
#       "upos": "ADJ",
#       "feats": "Case=Nom|Degree=Pos|Gender=Fem|Number=Sing",
#       "start_char": 901,
#       "end_char": 912
#     },
#     {
#       "id": 4,
#       "text": "программа",
#       "upos": "NOUN",
#       "feats": "Animacy=Inan|Case=Nom|Gender=Fem|Number=Sing",
#       "start_char": 913,
#       "end_char": 922
#     },
#     {
#       "id": 5,
#       "text": "и",
#       "upos": "CCONJ",
#       "start_char": 923,
#       "end_char": 924
#     },
#     {
#       "id": 6,
#       "text": "весёлый",
#       "upos": "ADJ",
#       "feats": "Case=Nom|Degree=Pos|Gender=Masc|Number=Sing",
#       "start_char": 925,
#       "end_char": 932
#     },
#     {
#       "id": 7,
#       "text": "ведущий",
#       "upos": "NOUN",
#       "feats": "Animacy=Anim|Case=Nom|Gender=Masc|Number=Sing",
#       "start_char": 933,
#       "end_char": 940
#     },
#     {
#       "id": 8,
#       "text": ".",
#       "upos": "PUNCT",
#       "start_char": 940,
#       "end_char": 941
#     }
#   ],
#   [
#     {
#       "id": 1,
#       "text": "В",
#       "upos": "ADP",
#       "start_char": 942,
#       "end_char": 943
#     },
#     {
#       "id": 2,
#       "text": "общем",
#       "upos": "ADJ",
#       "feats": "Case=Loc|Degree=Pos|Gender=Neut|Number=Sing",
#       "start_char": 944,
#       "end_char": 949
#     },
#     {
#       "id": 3,
#       "text": "я",
#       "upos": "PRON",
#       "feats": "Case=Nom|Number=Sing|Person=1",
#       "start_char": 950,
#       "end_char": 951
#     },
#     {
#       "id": 4,
#       "text": "остался",
#       "upos": "VERB",
#       "feats": "Aspect=Perf|Gender=Masc|Mood=Ind|Number=Sing|Tense=Past|VerbForm=Fin|Voice=Mid",
#       "start_char": 952,
#       "end_char": 959
#     },
#     {
#       "id": 5,
#       "text": "доволен",
#       "upos": "ADJ",
#       "feats": "Degree=Pos|Gender=Masc|Number=Sing|Variant=Short",
#       "start_char": 960,
#       "end_char": 967
#     },
#     {
#       "id": 6,
#       "text": "своим",
#       "upos": "DET",
#       "feats": "Case=Ins|Gender=Masc|Number=Sing",
#       "start_char": 968,
#       "end_char": 973
#     },
#     {
#       "id": 7,
#       "text": "выбором",
#       "upos": "NOUN",
#       "feats": "Animacy=Inan|Case=Ins|Gender=Masc|Number=Sing",
#       "start_char": 974,
#       "end_char": 981
#     },
#     {
#       "id": 8,
#       "text": ",",
#       "upos": "PUNCT",
#       "start_char": 981,
#       "end_char": 982
#     },
#     {
#       "id": 9,
#       "text": "и",
#       "upos": "CCONJ",
#       "start_char": 983,
#       "end_char": 984
#     },
#     {
#       "id": 10,
#       "text": "тем",
#       "upos": "PRON",
#       "feats": "Animacy=Inan|Case=Ins|Gender=Neut|Number=Sing",
#       "start_char": 985,
#       "end_char": 988
#     },
#     {
#       "id": 11,
#       "text": "как",
#       "upos": "SCONJ",
#       "start_char": 989,
#       "end_char": 992
#     },
#     {
#       "id": 12,
#       "text": "мы",
#       "upos": "PRON",
#       "feats": "Case=Nom|Number=Plur|Person=1",
#       "start_char": 993,
#       "end_char": 995
#     },
#     {
#       "id": 13,
#       "text": "провели",
#       "upos": "VERB",
#       "feats": "Aspect=Perf|Mood=Ind|Number=Plur|Tense=Past|VerbForm=Fin|Voice=Act",
#       "start_char": 996,
#       "end_char": 1003
#     },
#     {
#       "id": 14,
#       "text": "вечер",
#       "upos": "NOUN",
#       "feats": "Animacy=Inan|Case=Acc|Gender=Masc|Number=Sing",
#       "start_char": 1004,
#       "end_char": 1009
#     },
#     {
#       "id": 15,
#       "text": ",",
#       "upos": "PUNCT",
#       "start_char": 1009,
#       "end_char": 1010
#     },
#     {
#       "id": 16,
#       "text": "хороший",
#       "upos": "ADJ",
#       "feats": "Case=Nom|Degree=Pos|Gender=Masc|Number=Sing",
#       "start_char": 1011,
#       "end_char": 1018
#     },
#     {
#       "id": 17,
#       "text": "ресторан",
#       "upos": "NOUN",
#       "feats": "Animacy=Inan|Case=Nom|Gender=Masc|Number=Sing",
#       "start_char": 1019,
#       "end_char": 1027
#     },
#     {
#       "id": 18,
#       "text": ",",
#       "upos": "PUNCT",
#       "start_char": 1027,
#       "end_char": 1028
#     },
#     {
#       "id": 19,
#       "text": "уютный",
#       "upos": "ADJ",
#       "feats": "Case=Nom|Degree=Pos|Gender=Masc|Number=Sing",
#       "start_char": 1029,
#       "end_char": 1035
#     },
#     {
#       "id": 20,
#       "text": "и",
#       "upos": "CCONJ",
#       "start_char": 1036,
#       "end_char": 1037
#     },
#     {
#       "id": 21,
#       "text": "кухня",
#       "upos": "NOUN",
#       "feats": "Animacy=Inan|Case=Nom|Gender=Fem|Number=Sing",
#       "start_char": 1038,
#       "end_char": 1043
#     },
#     {
#       "id": 22,
#       "text": "хорошая",
#       "upos": "ADJ",
#       "feats": "Case=Nom|Degree=Pos|Gender=Fem|Number=Sing",
#       "start_char": 1044,
#       "end_char": 1051
#     },
#     {
#       "id": 23,
#       "text": ".",
#       "upos": "PUNCT",
#       "start_char": 1051,
#       "end_char": 1052
#     }
#   ],
#   [
#     {
#       "id": 1,
#       "text": "Руководству",
#       "upos": "NOUN",
#       "feats": "Animacy=Inan|Case=Dat|Gender=Neut|Number=Sing",
#       "start_char": 1053,
#       "end_char": 1064
#     },
#     {
#       "id": 2,
#       "text": "и",
#       "upos": "CCONJ",
#       "start_char": 1065,
#       "end_char": 1066
#     },
#     {
#       "id": 3,
#       "text": "персоналу",
#       "upos": "NOUN",
#       "feats": "Animacy=Inan|Case=Dat|Gender=Masc|Number=Sing",
#       "start_char": 1067,
#       "end_char": 1076
#     },
#     {
#       "id": 4,
#       "text": "СПАСИБО",
#       "upos": "NOUN",
#       "feats": "Animacy=Inan|Case=Nom|Gender=Neut|Number=Sing",
#       "start_char": 1077,
#       "end_char": 1084
#     },
#     {
#       "id": 5,
#       "text": ".",
#       "upos": "PUNCT",
#       "start_char": 1084,
#       "end_char": 1085
#     }
#   ]
# ]

# %%
reviews = {}
with open(path + 'train_reviews.txt') as f:
  for line in f:
    line = line.rstrip('\r\n').split('\t')
    reviews[line[0]] = line[1]


reviews_test = {}
with open(path + 'dev_reviews.txt') as f:
  for line in f:
    line = line.rstrip('\r\n').split('\t')
    reviews_test[line[0]] = line[1]

# %%
from collections import defaultdict
aspects = defaultdict(list)

# %%
with open(path + 'train_aspects.txt') as f:
  for line in f:
    line = line.rstrip('\r\n').split('\t')
    keys = ('category', 'mention', 'start', 'end', 'sentiment')
    # ['text_id', 'category', 'mention', 'start', 'end', 'sentiment']
    # тут можно отдельно запомнить начало и конец каждого упоминания
    aspects[line[0]].append(dict(zip(keys, line[1:])))

# %%
# здесь код для упоминаний из 1 токена
# ВАЖНО: для более длинных упоминаний нужно доделать ещё немного
markups = []
reviews_m = {}
poses = []
reviews_pos = {}
for text_id, text in reviews.items():
  processed = nlp(text)
  # print(processed)
  m = []
  r = []
  for token in processed.iter_tokens():
    # print(token.words[0].pos)
    add = False
    for mention in aspects[text_id]:
      if token.start_char == int(mention['start']) and token.end_char <= int(mention['end']):
      # if token.start_char == int(mention['start']) and token.end_char == int(mention['end']):
        # print(token.text, 'B-'+mention['category'])
        m.append('B-'+mention['category'])
        r.append(token.words[0].pos)
        add = True
        
      elif token.start_char > int(mention['start']) and token.end_char <= int(mention['end']):
        m.append('I-'+mention['category'])
        r.append(token.words[0].pos)
        add = True
      # if token.start_char == int(mention['start']) and token.end_char == int(mention['end']):
        # print(token.text, 'B-'+mention['category'])
        # m.append('B-'+mention['category'])
        # r.append(token.words[0].pos)
        # add = True
        # break
    if not add:
      # print(token.text, 'O')
      m.append( 'O')
      r.append(token.words[0].pos)
    reviews_m[text_id] = m
    markups.append(m)
    reviews_pos[text_id] = r
    poses.append(r)
  # break
print(markups[0])
print(poses[0])

print(markups[1])
print(poses[1])
# Out:
# ['O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'B-Whole', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'B-Whole', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'B-Whole', 'O', 'B-Service', 'I-Service', 'O', 'O', 'O', 'O', 'O', 'O', 'B-Service', 'O', 'O', 'B-Service', 'I-Service', 'O', 'O', 'O', 'O', 'O', 'O', 'B-Whole', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'B-Whole', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'B-Food', 'I-Food', 'O', 'O', 'O', 'O', 'O', 'B-Food', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'B-Service', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'B-Service', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'B-Interior', 'O', 'O', 'O', 'B-Interior', 'O', 'O', 'O', 'B-Interior', 'I-Interior', 'O', 'O', 'B-Interior', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'B-Whole', 'O', 'O', 'O', 'B-Food', 'O', 'O', 'B-Whole', 'O', 'B-Service', 'O', 'O']
# ['NOUN', 'ADJ', 'NOUN', 'VERB', 'PUNCT', 'ADV', 'PART', 'NOUN', 'VERB', 'PUNCT', 'VERB', 'VERB', 'NOUN', 'ADP', 'NOUN', 'ADP', 'PRON', 'VERB', 'ADJ', 'NOUN', 'NOUN', 'PUNCT', 'VERB', 'NOUN', 'PROPN', 'CCONJ', 'PROPN', 'VERB', 'SCONJ', 'CCONJ', 'PRON', 'AUX', 'ADJ', 'NOUN', 'PUNCT', 'CCONJ', 'ADP', 'NOUN', 'PRON', 'VERB', 'PUNCT', 'CCONJ', 'ADV', 'ADP', 'NOUN', 'PUNCT', 'NOUN', 'VERB', 'ADV', 'CCONJ', 'VERB', 'ADV', 'SCONJ', 'VERB', 'NOUN', 'PUNCT', 'VERB', 'ADJ', 'NOUN', 'PUNCT', 'SCONJ', 'VERB', 'VERB', 'ADV', 'VERB', 'NOUN', 'VERB', 'SCONJ', 'NOUN', 'PRON', 'VERB', 'ADV', 'ADJ', 'PUNCT', 'ADP', 'NOUN', 'VERB', 'NOUN', 'NUM', 'PUNCT', 'NUM', 'PUNCT', 'ADV', 'ADV', 'ADJ', 'NOUN', 'ADV', 'VERB', 'ADV', 'ADV', 'PUNCT', 'NOUN', 'ADV', 'ADJ', 'CCONJ', 'ADV', 'ADJ', 'PUNCT', 'PRON', 'CCONJ', 'DET', 'NOUN', 'VERB', 'PRON', 'PRON', 'PRON', 'VERB', 'PUNCT', 'CCONJ', 'VERB', 'PRON', 'ADV', 'PUNCT', 'NOUN', 'VERB', 'PART', 'PART', 'ADJ', 'ADJ', 'ADP', 'NOUN', 'PUNCT', 'CCONJ', 'NOUN', 'VERB', 'PRON', 'PRON', 'ADJ', 'PUNCT', 'ADJ', 'VERB', 'SCONJ', 'VERB', 'PRON', 'ADV', 'VERB', 'PUNCT', 'PART', 'ADV', 'ADV', 'ADV', 'PUNCT', 'CCONJ', 'ADV', 'PUNCT', 'NOUN', 'ADJ', 'PUNCT', 'ADJ', 'NOUN', 'PUNCT', 'ADV', 'ADJ', 'ADJ', 'NOUN', 'CCONJ', 'ADJ', 'NOUN', 'PUNCT', 'ADP', 'ADJ', 'PRON', 'VERB', 'ADJ', 'DET', 'NOUN', 'PUNCT', 'CCONJ', 'PRON', 'SCONJ', 'PRON', 'VERB', 'NOUN', 'PUNCT', 'ADJ', 'NOUN', 'PUNCT', 'ADJ', 'CCONJ', 'NOUN', 'ADJ', 'PUNCT', 'NOUN', 'CCONJ', 'NOUN', 'NOUN', 'PUNCT']
# ['O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'B-Whole', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'B-Whole', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'B-Whole', 'O', 'B-Service', 'I-Service', 'O', 'O', 'O', 'O', 'O', 'O', 'B-Service', 'O', 'O', 'B-Service', 'I-Service', 'O', 'O', 'O', 'O', 'O', 'O', 'B-Whole', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'B-Whole', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'B-Food', 'I-Food', 'O', 'O', 'O', 'O', 'O', 'B-Food', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'B-Service', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'B-Service', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'B-Interior', 'O', 'O', 'O', 'B-Interior', 'O', 'O', 'O', 'B-Interior', 'I-Interior', 'O', 'O', 'B-Interior', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'B-Whole', 'O', 'O', 'O', 'B-Food', 'O', 'O', 'B-Whole', 'O', 'B-Service', 'O', 'O']
# ['NOUN', 'ADJ', 'NOUN', 'VERB', 'PUNCT', 'ADV', 'PART', 'NOUN', 'VERB', 'PUNCT', 'VERB', 'VERB', 'NOUN', 'ADP', 'NOUN', 'ADP', 'PRON', 'VERB', 'ADJ', 'NOUN', 'NOUN', 'PUNCT', 'VERB', 'NOUN', 'PROPN', 'CCONJ', 'PROPN', 'VERB', 'SCONJ', 'CCONJ', 'PRON', 'AUX', 'ADJ', 'NOUN', 'PUNCT', 'CCONJ', 'ADP', 'NOUN', 'PRON', 'VERB', 'PUNCT', 'CCONJ', 'ADV', 'ADP', 'NOUN', 'PUNCT', 'NOUN', 'VERB', 'ADV', 'CCONJ', 'VERB', 'ADV', 'SCONJ', 'VERB', 'NOUN', 'PUNCT', 'VERB', 'ADJ', 'NOUN', 'PUNCT', 'SCONJ', 'VERB', 'VERB', 'ADV', 'VERB', 'NOUN', 'VERB', 'SCONJ', 'NOUN', 'PRON', 'VERB', 'ADV', 'ADJ', 'PUNCT', 'ADP', 'NOUN', 'VERB', 'NOUN', 'NUM', 'PUNCT', 'NUM', 'PUNCT', 'ADV', 'ADV', 'ADJ', 'NOUN', 'ADV', 'VERB', 'ADV', 'ADV', 'PUNCT', 'NOUN', 'ADV', 'ADJ', 'CCONJ', 'ADV', 'ADJ', 'PUNCT', 'PRON', 'CCONJ', 'DET', 'NOUN', 'VERB', 'PRON', 'PRON', 'PRON', 'VERB', 'PUNCT', 'CCONJ', 'VERB', 'PRON', 'ADV', 'PUNCT', 'NOUN', 'VERB', 'PART', 'PART', 'ADJ', 'ADJ', 'ADP', 'NOUN', 'PUNCT', 'CCONJ', 'NOUN', 'VERB', 'PRON', 'PRON', 'ADJ', 'PUNCT', 'ADJ', 'VERB', 'SCONJ', 'VERB', 'PRON', 'ADV', 'VERB', 'PUNCT', 'PART', 'ADV', 'ADV', 'ADV', 'PUNCT', 'CCONJ', 'ADV', 'PUNCT', 'NOUN', 'ADJ', 'PUNCT', 'ADJ', 'NOUN', 'PUNCT', 'ADV', 'ADJ', 'ADJ', 'NOUN', 'CCONJ', 'ADJ', 'NOUN', 'PUNCT', 'ADP', 'ADJ', 'PRON', 'VERB', 'ADJ', 'DET', 'NOUN', 'PUNCT', 'CCONJ', 'PRON', 'SCONJ', 'PRON', 'VERB', 'NOUN', 'PUNCT', 'ADJ', 'NOUN', 'PUNCT', 'ADJ', 'CCONJ', 'NOUN', 'ADJ', 'PUNCT', 'NOUN', 'CCONJ', 'NOUN', 'NOUN', 'PUNCT']

# %%
reviews_m.keys()
# Out:
# dict_keys(['3976', '30808', '14031', '2495', '38835', '1368', '7890', '6668', '9662', '18430', '14190', '2107', '3705', '33591', '34956', '3385', '33520', '12366', '29321', '22970', '35867', '36512', '36926', '1200', '15159', '18220', '36359', '13823', '1105', '32856', '32367', '6155', '37975', '32840', '23858', '10625', '25861', '4106', '27816', '18518', '36017', '29395', '27629', '10645', '34045', '6366', '8411', '18003', '19677', '11388', '28083', '6376', '11421', '24214', '31963', '3152', '27375', '10663', '25709', '719', '34607', '18780', '13225', '37516', '30744', '37473', '34282', '34232', '19265', '22975', '22015', '8555', '35486', '37819', '10942', '5037', '7824', '28745', '11825', '19503', '26330', '33693', '19383', '8759', '1434', '12203', '12880', '2073', '37611', '12341', '2692', '36049', '17572', '20784', '36483', '1751', '14568', '1032', '13100', '1511', '9036', '27841', '3452', '38077', '32040', '26887', '35613', '37220', '31004', '5648', '7079', '35635', '11267', '1052', '30148', '24916', '13186', '1515', '797', '22386', '3906', '21574', '27040', '34196', '32442', '6880', '31140', '19467', '21059', '33252', '36085', '33816', '32995', '9870', '4308', '31778', '36079', '20086', '35863', '11770', '29298', '37784', '23369', '15335', '12678', '9289', '20021', '11027', '8996', '1427', '3202', '18148', '16568', '37364', '10231', '28585', '1878', '32859', '28612', '19746', '2168', '35904', '20862', '36407', '11532', '32926', '25960', '33622', '37428', '34889', '280', '10985', '9721', '24275', '6564', '18983', '13623', '12814', '16714', '26152', '785', '33538', '13252', '1749', '17999', '19817', '36948', '34402', '3236', '3552', '9230', '28112', '34710', '7417', '27169', '9076', '17475', '38772', '9776', '5155', '11355', '33798', '31071', '3231', '3647', '20861', '2006', '36589', '3875', '27569', '2089', '1269', '35325', '15423', '4658', '12372', '34334', '3749', '30201', '2364', '3762', '15758', '30368', '7053', '5974', '2747', '25753', '24132', '36166', '33524', '32513', '28710', '9837', '9216', '16761', '36321', '33598', '33912', '10825', '16151', '8589', '21399', '37070', '15567', '35620', '13748', '7011', '34228', '18372', '19439', '2606', '11058', '10099', '37391', '10354', '24217', '21856', '34307', '1308', '14539', '38299', '5928', '32206', '16378', '12131', '7193', '24713', '36126', '27620', '2468', '7982', '13912', '7154', '18756', '16676', '27925', '20397', '10798', '343', '6962', '9878', '28258', '33043', '16630'])

# %%
markups_test = []
reviews_m_test = {}
poses_test = []
reviews_pos_test = {}
for text_id, text in reviews_test.items():
  processed = nlp(text)
  # print(processed)
  m = []
  r = []
  for token in processed.iter_tokens():
    # print(token.words[0].pos)
    add = False
    for mention in aspects[text_id]:
      if token.start_char == int(mention['start']) and token.end_char <= int(mention['end']):
      # if token.start_char == int(mention['start']) and token.end_char == int(mention['end']):
        # print(token.text, 'B-'+mention['category'])
        m.append('B-'+mention['category'])
        r.append(token.words[0].pos)
        add = True
        
      elif token.start_char > int(mention['start']) and token.end_char <= int(mention['end']):
        m.append('I-'+mention['category'])
        r.append(token.words[0].pos)
        add = True

    if not add:
      # print(token.text, 'O')
      m.append('O')
      r.append(token.words[0].pos)
    reviews_m_test[text_id] = m
    markups_test .append(m)
    reviews_pos_test [text_id] = r
    poses_test .append(r)

print(markups_test [0])
print(poses_test [0])

print(markups_test [1])
print(poses_test [1])
# Out:
# ['O', 'O', 'B-Whole', 'I-Whole', 'I-Whole', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'B-Service', 'B-Service', 'O', 'O', 'O', 'B-Service', 'O', 'B-Service', 'I-Service', 'I-Service', 'O', 'B-Service', 'I-Service', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'B-Service', 'O', 'B-Service', 'I-Service', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'B-Whole', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'B-Service', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'B-Food', 'I-Food', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'B-Price', 'O', 'O', 'O', 'O', 'O', 'B-Whole', 'O', 'O', 'O', 'B-Food', 'O', 'O', 'B-Price', 'O', 'O', 'O', 'B-Service', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'B-Whole', 'O', 'O', 'O', 'O', 'O', 'O']
# ['VERB', 'ADP', 'PUNCT', 'NOUN', 'PUNCT', 'ADV', 'PUNCT', 'PART', 'VERB', 'ADP', 'PRON', 'PUNCT', 'SCONJ', 'AUX', 'ADJ', 'NOUN', 'PUNCT', 'NOUN', 'NUM', 'NOUN', 'PUNCT', 'CCONJ', 'ADV', 'ADV', 'NOUN', 'PUNCT', 'PART', 'PART', 'VERB', 'VERB', 'PUNCT', 'PRON', 'VERB', 'NOUN', 'PUNCT', 'ADJ', 'ADJ', 'NOUN', 'PUNCT', 'VERB', 'ADP', 'NOUN', 'CCONJ', 'VERB', 'NOUN', 'PUNCT', 'PUNCT', 'PUNCT', 'ADP', 'NUM', 'NOUN', 'VERB', 'NOUN', 'PUNCT', 'VERB', 'NOUN', 'CCONJ', 'VERB', 'PUNCT', 'PUNCT', 'PUNCT', 'VERB', 'ADV', 'PRON', 'VERB', 'PRON', 'VERB', 'VERB', 'ADV', 'PUNCT', 'NOUN', 'AUX', 'ADJ', 'PUNCT', 'ADV', 'PRON', 'VERB', 'PUNCT', 'NOUN', 'AUX', 'ADJ', 'PUNCT', 'ADV', 'ADJ', 'ADP', 'DET', 'NOUN', 'PUNCT', 'ADP', 'ADJ', 'NOUN', 'PRON', 'PART', 'VERB', 'SCONJ', 'VERB', 'NOUN', 'PUNCT', 'PUNCT', 'PUNCT', 'NOUN', 'NOUN', 'PUNCT', 'ADP', 'NOUN', 'PUNCT', 'VERB', 'ADV', 'ADJ', 'CCONJ', 'ADJ', 'PUNCT', 'ADV', 'VERB', 'DET', 'NOUN', 'PUNCT', 'ADP', 'ADJ', 'ADV', 'ADJ', 'NOUN', 'PUNCT', 'ADJ', 'ADJ', 'NOUN', 'PUNCT', 'ADJ', 'NOUN', 'CCONJ', 'ADJ', 'NOUN', 'NOUN', 'PUNCT', 'PRON', 'ADV', 'PRON', 'VERB', 'PUNCT', 'NOUN', 'DET', 'NOUN', 'PUNCT', 'ADV', 'VERB', 'ADP', 'NOUN', 'PUNCT']
# ['O', 'O', 'B-Whole', 'I-Whole', 'I-Whole', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'B-Service', 'B-Service', 'O', 'O', 'O', 'B-Service', 'O', 'B-Service', 'I-Service', 'I-Service', 'O', 'B-Service', 'I-Service', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'B-Service', 'O', 'B-Service', 'I-Service', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'B-Whole', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'B-Service', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'B-Food', 'I-Food', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'B-Price', 'O', 'O', 'O', 'O', 'O', 'B-Whole', 'O', 'O', 'O', 'B-Food', 'O', 'O', 'B-Price', 'O', 'O', 'O', 'B-Service', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'B-Whole', 'O', 'O', 'O', 'O', 'O', 'O']
# ['VERB', 'ADP', 'PUNCT', 'NOUN', 'PUNCT', 'ADV', 'PUNCT', 'PART', 'VERB', 'ADP', 'PRON', 'PUNCT', 'SCONJ', 'AUX', 'ADJ', 'NOUN', 'PUNCT', 'NOUN', 'NUM', 'NOUN', 'PUNCT', 'CCONJ', 'ADV', 'ADV', 'NOUN', 'PUNCT', 'PART', 'PART', 'VERB', 'VERB', 'PUNCT', 'PRON', 'VERB', 'NOUN', 'PUNCT', 'ADJ', 'ADJ', 'NOUN', 'PUNCT', 'VERB', 'ADP', 'NOUN', 'CCONJ', 'VERB', 'NOUN', 'PUNCT', 'PUNCT', 'PUNCT', 'ADP', 'NUM', 'NOUN', 'VERB', 'NOUN', 'PUNCT', 'VERB', 'NOUN', 'CCONJ', 'VERB', 'PUNCT', 'PUNCT', 'PUNCT', 'VERB', 'ADV', 'PRON', 'VERB', 'PRON', 'VERB', 'VERB', 'ADV', 'PUNCT', 'NOUN', 'AUX', 'ADJ', 'PUNCT', 'ADV', 'PRON', 'VERB', 'PUNCT', 'NOUN', 'AUX', 'ADJ', 'PUNCT', 'ADV', 'ADJ', 'ADP', 'DET', 'NOUN', 'PUNCT', 'ADP', 'ADJ', 'NOUN', 'PRON', 'PART', 'VERB', 'SCONJ', 'VERB', 'NOUN', 'PUNCT', 'PUNCT', 'PUNCT', 'NOUN', 'NOUN', 'PUNCT', 'ADP', 'NOUN', 'PUNCT', 'VERB', 'ADV', 'ADJ', 'CCONJ', 'ADJ', 'PUNCT', 'ADV', 'VERB', 'DET', 'NOUN', 'PUNCT', 'ADP', 'ADJ', 'ADV', 'ADJ', 'NOUN', 'PUNCT', 'ADJ', 'ADJ', 'NOUN', 'PUNCT', 'ADJ', 'NOUN', 'CCONJ', 'ADJ', 'NOUN', 'NOUN', 'PUNCT', 'PRON', 'ADV', 'PRON', 'VERB', 'PUNCT', 'NOUN', 'DET', 'NOUN', 'PUNCT', 'ADV', 'VERB', 'ADP', 'NOUN', 'PUNCT']

# %% [markdown]
# ## CRF
#
# Популярный алгоритм для разметки последовательностей. Попробуем сначала на задаче NER с помощью [sklearn-crfsuite](https://sklearn-crfsuite.readthedocs.io/en/latest/api.html)
#
# Возьмём корпус WikiNER:

# %%
# !pip install -U 'scikit-learn<0.24'
# Out:
# Requirement already satisfied: scikit-learn<0.24 in /usr/local/lib/python3.7/dist-packages (0.23.2)
# Requirement already satisfied: joblib>=0.11 in /usr/local/lib/python3.7/dist-packages (from scikit-learn<0.24) (1.1.0)
# Requirement already satisfied: scipy>=0.19.1 in /usr/local/lib/python3.7/dist-packages (from scikit-learn<0.24) (1.4.1)
# Requirement already satisfied: threadpoolctl>=2.0.0 in /usr/local/lib/python3.7/dist-packages (from scikit-learn<0.24) (3.0.0)
# Requirement already satisfied: numpy>=1.13.3 in /usr/local/lib/python3.7/dist-packages (from scikit-learn<0.24) (1.19.5)

# %%
# from sklearn.model_selection import train_test_split

# %%
# !wget https://github.com/dice-group/FOX/raw/master/input/Wikiner/aij-wikiner-ru-wp3.bz2

# %%
# !pip install corus

# %%
# from corus import load_wikiner
# data = list(load_wikiner('aij-wikiner-ru-wp3.bz2'))

# %% [markdown]
# Посмотрим на разметку:

# %%
for key, value in reviews.items():
  print(key)
  print(value)
  print(reviews_m[key])
  break
# Out:
# 3976
# День 8-го марта прошёл, можно и итоги подвести. Решил написать отзыв о ресторане в котором отметили прекрасный весений праздник, прочитал отзывы edik077 и Rules77777и понял что либо мы были вразных ресторанах, либо у ребят что-то незаладилось. Но теперь о ресторане. Столик бронировали заранее и сделали так как предложил администратор т.е. сделали предварительный заказ, когда придя увидели полностью заполненый ресторан поняли что совет нам дали действительно правильный, в ресторане было человек 70-80, тут действительно горячее блюдо можно ждать весьма долго. Меню достаточно разнообразное и весьма вкусное, мне и моим друзьям понравилось всё что нам принесли, а принесли нам немало. Обслуживание может и не самое лучьшее в городе, но официанты делали всё что нужно. Должен сказать что ждать нам всёравно пришлось, не очень долго конечно, но всё-же. Интерьер хороший, удобные диваны.Очень хорошая музыкальная программа и весёлый ведущий. В общем я остался доволен своим выбором, и тем как мы провели вечер, хороший ресторан, уютный и кухня хорошая. Руководству и персоналу СПАСИБО.
# ['O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'B-Whole', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'B-Whole', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'B-Whole', 'O', 'B-Service', 'I-Service', 'O', 'O', 'O', 'O', 'O', 'O', 'B-Service', 'O', 'O', 'B-Service', 'I-Service', 'O', 'O', 'O', 'O', 'O', 'O', 'B-Whole', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'B-Whole', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'B-Food', 'I-Food', 'O', 'O', 'O', 'O', 'O', 'B-Food', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'B-Service', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'B-Service', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'B-Interior', 'O', 'O', 'O', 'B-Interior', 'O', 'O', 'O', 'B-Interior', 'I-Interior', 'O', 'O', 'B-Interior', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'B-Whole', 'O', 'O', 'O', 'B-Food', 'O', 'O', 'B-Whole', 'O', 'B-Service', 'O', 'O']

# %%
for key, value in reviews_test.items():
  print(key)
  print(value)
  print(reviews_m[key])
  break
# Out:
# 13823
# Зашли в"аппетит" случайно.Не смотря на то,что был будний день( вторник 14 сентября) и достаточно много народа, все же решили остаться.нас встретил менеджер- темноволосая стройная девушка, проводила к столу и дала меню...Спустя 5 минут пришла официантка, приняла заказ и удалилась...Посмотрев вокруг мы подумали что ждать придется долго- ресторан был полон, однако мы ошиблись , ожидание было недолгим- вполне приемлимым для любого заведения,за приятной беседой мы не заметили как прошло время...Бизнес ланч, на удивление, оказался очень вкусным и сытным- вполне соответствует своей цене. В общем очень хорошее место, разнообразное вкусное меню, приемлемые цены и высокое качество обслуживания! нам очень все понравилось. спасибо этому заведению! обязательно придем на выходных.
# ['O', 'O', 'B-Whole', 'I-Whole', 'I-Whole', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'B-Service', 'B-Service', 'O', 'O', 'O', 'B-Service', 'O', 'B-Service', 'I-Service', 'I-Service', 'O', 'B-Service', 'I-Service', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'B-Service', 'O', 'B-Service', 'I-Service', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'B-Whole', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'B-Service', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'B-Food', 'I-Food', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'B-Price', 'O', 'O', 'O', 'O', 'O', 'B-Whole', 'O', 'O', 'O', 'B-Food', 'O', 'O', 'B-Price', 'O', 'O', 'O', 'B-Service', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'B-Whole', 'O', 'O', 'O', 'O', 'O', 'O']

# %%
# data[0]

# %%
# data[0].tokens

# %%
# data = data[:100000]

# %% [markdown]
# Поделим датасет на train и test:

# %%
# train_sents, test_sents = train_test_split(data)

# %% [markdown]
# **Обучение CRF**

# %%
# !pip install sklearn-crfsuite
# Out:
# Requirement already satisfied: sklearn-crfsuite in /usr/local/lib/python3.7/dist-packages (0.3.6)
# Requirement already satisfied: tqdm>=2.0 in /usr/local/lib/python3.7/dist-packages (from sklearn-crfsuite) (4.62.3)
# Requirement already satisfied: python-crfsuite>=0.8.3 in /usr/local/lib/python3.7/dist-packages (from sklearn-crfsuite) (0.9.7)
# Requirement already satisfied: tabulate in /usr/local/lib/python3.7/dist-packages (from sklearn-crfsuite) (0.8.9)
# Requirement already satisfied: six in /usr/local/lib/python3.7/dist-packages (from sklearn-crfsuite) (1.15.0)

# %%
import sklearn_crfsuite
from sklearn_crfsuite import scorers
from sklearn_crfsuite import metrics

# %% [markdown]
# Заведём экстрактор признаков и тегов:

# %%
reviews_m_test.keys()
# Out:
# dict_keys(['13823', '1427', '16714', '797', '34710', '33798', '2073', '785', '1434', '22386', '32442', '15423', '7193', '13100', '35635', '2107', '36085', '7824', '34045', '11421', '36126', '13186', '9721', '28083', '30744', '3976', '27040', '33591', '28258', '19503', '37391', '14568', '2495', '34402', '33524', '27375', '31071', '25960', '9837', '27841', '3231', '18780', '10798', '12131', '26152', '28112', '7011', '33043', '20862', '33252', '34956', '9289', '14539', '15567', '36926', '36512', '11532', '5155', '31004', '2606', '3552', '29395', '7154', '35325', '5974', '19817', '9216', '8996', '38299', '37819', '11770'])

# %%
sents = {}
for key, value in reviews.items():
  toks = []
  for i, tok in enumerate(value.split()):
    toks.append({'text': tok, 'tag':reviews_m[key][i], 'pos': reviews_pos[key][i]})
  sents[key] = {'tokens': toks}
  # print(key, value)
  # print(reviews_m[key])
  # print(reviews_pos[key])
  # break
# sents

sents_test = {}
for key, value in reviews_test.items():
  toks = []
  for i, tok in enumerate(value.split()):
    toks.append({'text': tok, 'tag':reviews_m_test[key][i], 'pos': reviews_pos_test[key][i]})
  sents_test[key] = {'tokens': toks}

# %%
def word2features(sent, i):
    # достаёт фичи для i-го токена в предложении
    word = sent[i]['text']
    postag = sent[i]['pos']
    
    features = {
        'word.lower()': word.lower(),
        'word[-3:]': word[-3:],
        'word[-2:]': word[-2:],
        'word.isupper()': word.isupper(),
        'word.istitle()': word.istitle(),
        'word.isdigit()': word.isdigit(),
        'postag': postag,
    }
    if i > 0:
        word1 = sent[i-1]['text']
        postag1 = sent[i-1]['pos']
        features.update({
            '-1:word.lower()': word1.lower(),
            '-1:word.istitle()': word1.istitle(),
            '-1:word.isupper()': word1.isupper(),
            '-1:postag': postag1,
        })
    else:
        features['BOS'] = True
        
    if i < len(sent)-1:
        word1 = sent[i+1]['text']
        postag1 = sent[i+1]['pos']
        features.update({
            '+1:word.lower()': word1.lower(),
            '+1:word.istitle()': word1.istitle(),
            '+1:word.isupper()': word1.isupper(),
            '+1:postag': postag1,
            '+1:postag[:2]': postag1[:2],
        })
    else:
        features['EOS'] = True
                
    return features


def sent2features(sent):
    # достаёт фичи для всех токенов в предложении
    return [word2features(sent['tokens'], i) for i in range(len(sent['tokens']))]

def sent2labels(sent):
    return [label['tag'] for label in sent['tokens']]

def sent2tokens(sent):
    return [label['text'] for label in sent['tokens']]

# %%
for key, value in sents.items():
  print(key)
  print(value)
  print(sent2features(value))
  break
# Out:
# 3976
# {'tokens': [{'text': 'День', 'tag': 'O', 'pos': 'NOUN'}, {'text': '8-го', 'tag': 'O', 'pos': 'ADJ'}, {'text': 'марта', 'tag': 'O', 'pos': 'NOUN'}, {'text': 'прошёл,', 'tag': 'O', 'pos': 'VERB'}, {'text': 'можно', 'tag': 'O', 'pos': 'PUNCT'}, {'text': 'и', 'tag': 'O', 'pos': 'ADV'}, {'text': 'итоги', 'tag': 'O', 'pos': 'PART'}, {'text': 'подвести.', 'tag': 'O', 'pos': 'NOUN'}, {'text': 'Решил', 'tag': 'O', 'pos': 'VERB'}, {'text': 'написать', 'tag': 'O', 'pos': 'PUNCT'}, {'text': 'отзыв', 'tag': 'O', 'pos': 'VERB'}, {'text': 'о', 'tag': 'O', 'pos': 'VERB'}, {'text': 'ресторане', 'tag': 'O', 'pos': 'NOUN'}, {'text': 'в', 'tag': 'O', 'pos': 'ADP'}, {'text': 'котором', 'tag': 'B-Whole', 'pos': 'NOUN'}, {'text': 'отметили', 'tag': 'O', 'pos': 'ADP'}, {'text': 'прекрасный', 'tag': 'O', 'pos': 'PRON'}, {'text': 'весений', 'tag': 'O', 'pos': 'VERB'}, {'text': 'праздник,', 'tag': 'O', 'pos': 'ADJ'}, {'text': 'прочитал', 'tag': 'O', 'pos': 'NOUN'}, {'text': 'отзывы', 'tag': 'O', 'pos': 'NOUN'}, {'text': 'edik077', 'tag': 'O', 'pos': 'PUNCT'}, {'text': 'и', 'tag': 'O', 'pos': 'VERB'}, {'text': 'Rules77777и', 'tag': 'O', 'pos': 'NOUN'}, {'text': 'понял', 'tag': 'O', 'pos': 'PROPN'}, {'text': 'что', 'tag': 'O', 'pos': 'CCONJ'}, {'text': 'либо', 'tag': 'O', 'pos': 'PROPN'}, {'text': 'мы', 'tag': 'O', 'pos': 'VERB'}, {'text': 'были', 'tag': 'O', 'pos': 'SCONJ'}, {'text': 'вразных', 'tag': 'O', 'pos': 'CCONJ'}, {'text': 'ресторанах,', 'tag': 'O', 'pos': 'PRON'}, {'text': 'либо', 'tag': 'O', 'pos': 'AUX'}, {'text': 'у', 'tag': 'O', 'pos': 'ADJ'}, {'text': 'ребят', 'tag': 'B-Whole', 'pos': 'NOUN'}, {'text': 'что-то', 'tag': 'O', 'pos': 'PUNCT'}, {'text': 'незаладилось.', 'tag': 'O', 'pos': 'CCONJ'}, {'text': 'Но', 'tag': 'O', 'pos': 'ADP'}, {'text': 'теперь', 'tag': 'O', 'pos': 'NOUN'}, {'text': 'о', 'tag': 'O', 'pos': 'PRON'}, {'text': 'ресторане.', 'tag': 'O', 'pos': 'VERB'}, {'text': 'Столик', 'tag': 'O', 'pos': 'PUNCT'}, {'text': 'бронировали', 'tag': 'O', 'pos': 'CCONJ'}, {'text': 'заранее', 'tag': 'O', 'pos': 'ADV'}, {'text': 'и', 'tag': 'O', 'pos': 'ADP'}, {'text': 'сделали', 'tag': 'B-Whole', 'pos': 'NOUN'}, {'text': 'так', 'tag': 'O', 'pos': 'PUNCT'}, {'text': 'как', 'tag': 'B-Service', 'pos': 'NOUN'}, {'text': 'предложил', 'tag': 'I-Service', 'pos': 'VERB'}, {'text': 'администратор', 'tag': 'O', 'pos': 'ADV'}, {'text': 'т.е.', 'tag': 'O', 'pos': 'CCONJ'}, {'text': 'сделали', 'tag': 'O', 'pos': 'VERB'}, {'text': 'предварительный', 'tag': 'O', 'pos': 'ADV'}, {'text': 'заказ,', 'tag': 'O', 'pos': 'SCONJ'}, {'text': 'когда', 'tag': 'O', 'pos': 'VERB'}, {'text': 'придя', 'tag': 'B-Service', 'pos': 'NOUN'}, {'text': 'увидели', 'tag': 'O', 'pos': 'PUNCT'}, {'text': 'полностью', 'tag': 'O', 'pos': 'VERB'}, {'text': 'заполненый', 'tag': 'B-Service', 'pos': 'ADJ'}, {'text': 'ресторан', 'tag': 'I-Service', 'pos': 'NOUN'}, {'text': 'поняли', 'tag': 'O', 'pos': 'PUNCT'}, {'text': 'что', 'tag': 'O', 'pos': 'SCONJ'}, {'text': 'совет', 'tag': 'O', 'pos': 'VERB'}, {'text': 'нам', 'tag': 'O', 'pos': 'VERB'}, {'text': 'дали', 'tag': 'O', 'pos': 'ADV'}, {'text': 'действительно', 'tag': 'O', 'pos': 'VERB'}, {'text': 'правильный,', 'tag': 'B-Whole', 'pos': 'NOUN'}, {'text': 'в', 'tag': 'O', 'pos': 'VERB'}, {'text': 'ресторане', 'tag': 'O', 'pos': 'SCONJ'}, {'text': 'было', 'tag': 'O', 'pos': 'NOUN'}, {'text': 'человек', 'tag': 'O', 'pos': 'PRON'}, {'text': '70-80,', 'tag': 'O', 'pos': 'VERB'}, {'text': 'тут', 'tag': 'O', 'pos': 'ADV'}, {'text': 'действительно', 'tag': 'O', 'pos': 'ADJ'}, {'text': 'горячее', 'tag': 'O', 'pos': 'PUNCT'}, {'text': 'блюдо', 'tag': 'O', 'pos': 'ADP'}, {'text': 'можно', 'tag': 'B-Whole', 'pos': 'NOUN'}, {'text': 'ждать', 'tag': 'O', 'pos': 'VERB'}, {'text': 'весьма', 'tag': 'O', 'pos': 'NOUN'}, {'text': 'долго.', 'tag': 'O', 'pos': 'NUM'}, {'text': 'Меню', 'tag': 'O', 'pos': 'PUNCT'}, {'text': 'достаточно', 'tag': 'O', 'pos': 'NUM'}, {'text': 'разнообразное', 'tag': 'O', 'pos': 'PUNCT'}, {'text': 'и', 'tag': 'O', 'pos': 'ADV'},  ...
# [{'word.lower()': 'день', 'word[-3:]': 'ень', 'word[-2:]': 'нь', 'word.isupper()': False, 'word.istitle()': True, 'word.isdigit()': False, 'postag': 'NOUN', 'BOS': True, '+1:word.lower()': '8-го', '+1:word.istitle()': False, '+1:word.isupper()': False, '+1:postag': 'ADJ', '+1:postag[:2]': 'AD'}, {'word.lower()': '8-го', 'word[-3:]': '-го', 'word[-2:]': 'го', 'word.isupper()': False, 'word.istitle()': False, 'word.isdigit()': False, 'postag': 'ADJ', '-1:word.lower()': 'день', '-1:word.istitle()': True, '-1:word.isupper()': False, '-1:postag': 'NOUN', '+1:word.lower()': 'марта', '+1:word.istitle()': False, '+1:word.isupper()': False, '+1:postag': 'NOUN', '+1:postag[:2]': 'NO'}, {'word.lower()': 'марта', 'word[-3:]': 'рта', 'word[-2:]': 'та', 'word.isupper()': False, 'word.istitle()': False, 'word.isdigit()': False, 'postag': 'NOUN', '-1:word.lower()': '8-го', '-1:word.istitle()': False, '-1:word.isupper()': False, '-1:postag': 'ADJ', '+1:word.lower()': 'прошёл,', '+1:word.istitle()': False, '+1:word.isupper()': False, '+1:postag': 'VERB', '+1:postag[:2]': 'VE'}, {'word.lower()': 'прошёл,', 'word[-3:]': 'ёл,', 'word[-2:]': 'л,', 'word.isupper()': False, 'word.istitle()': False, 'word.isdigit()': False, 'postag': 'VERB', '-1:word.lower()': 'марта', '-1:word.istitle()': False, '-1:word.isupper()': False, '-1:postag': 'NOUN', '+1:word.lower()': 'можно', '+1:word.istitle()': False, '+1:word.isupper()': False, '+1:postag': 'PUNCT', '+1:postag[:2]': 'PU'}, {'word.lower()': 'можно', 'word[-3:]': 'жно', 'word[-2:]': 'но', 'word.isupper()': False, 'word.istitle()': False, 'word.isdigit()': False, 'postag': 'PUNCT', '-1:word.lower()': 'прошёл,', '-1:word.istitle()': False, '-1:word.isupper()': False, '-1:postag': 'VERB', '+1:word.lower()': 'и', '+1:word.istitle()': False, '+1:word.isupper()': False, '+1:postag': 'ADV', '+1:postag[:2]': 'AD'}, {'word.lower()': 'и', 'word[-3:]': 'и', 'word[-2:]': 'и', 'word.isupper()': False, 'word.istitle()': False, 'word.isdigit()': False, 'postag': 'ADV', '-1:word.lower()': 'можно', '-1:word.istitle()': False, '-1:word.isupper()': False, '-1:postag': 'PUNCT', '+1:word.lower()': 'итоги', '+1:word.istitle()': False, '+1:word.isupper()': False, '+1:postag': 'PART', '+1:postag[:2]': 'PA'}, {'word.lower()': 'итоги', 'word[-3:]': 'оги', 'word[-2:]': 'ги', 'word.isupper()': False, 'word.istitle()': False, 'word.isdigit()': False, 'postag': 'PART', '-1:word.lower()': 'и', '-1:word.istitle()': False, '-1:word.isupper()': False, '-1:postag': 'ADV', '+1:word.lower()': 'подвести.', '+1:word.istitle()': False, '+1:word.isupper()': False, '+1:postag': 'NOUN', '+1:postag[:2]': 'NO'}, {'word.lower()': 'подвести.', 'word[-3:]': 'ти.', 'word[-2:]': 'и.', 'word.isupper()': False, 'word.istitle()': False, 'word.isdigit()': False, 'postag': 'NOUN', '-1:word.lower()': 'итоги', '-1:word.istitle()': False, '-1:word.isupper()': False, '-1:postag': 'PART', '+1:word.lower()': 'решил', '+1:word.istitle()': True, '+1:word.isupper()': False, '+1:postag': 'VERB', '+1:postag[:2]': 'VE'}, {'word.lower()': 'решил', 'word[-3:]': 'шил', 'word[-2:]': 'ил', 'word.isupper()': False, 'word.istitle()': True, 'word.isdigit()': False, 'postag': 'VERB', '-1:word.lower()': 'подвести.', '-1:word.istitle()': False, '-1:word.isupper()': False, '-1:postag': 'NOUN', '+1:word.lower()': 'написать', '+1:word.istitle()': False, '+1:word.isupper()': False, '+1:postag': 'PUNCT', '+1:postag[:2]': 'PU'}, {'word.lower()': 'написать', 'word[-3:]': 'ать', 'word[-2:]': 'ть', 'word.isupper()': False, 'word.istitle()': False, 'word.isdigit()': False, 'postag': 'PUNCT', '-1:word.lower()': 'решил', '-1:word.istitle()': True, '-1:word.isupper()': False, '-1:postag': 'VERB', '+1:word.lower()': 'отзыв', '+1:word.istitle()': False, '+1:word.isupper()': False, '+1:postag': 'VERB', '+1:postag[:2]': 'VE'}, {'word.lower()': 'отзыв', 'word[-3:]': 'зыв', 'word[-2:]': 'ыв', 'word.isupper()': False, 'word.istitle()': False, 'word.isdigit()': False, 'postag': 'VERB', '-1:word.lower( ...

# %%
X_train = [sent2features(value) for key, value in sents.items()]

# %%
for key, value in sents.items():
  print(key)
  print(value)
  print(sent2labels(value))
  break
# Out:
# 3976
# {'tokens': [{'text': 'День', 'tag': 'O', 'pos': 'NOUN'}, {'text': '8-го', 'tag': 'O', 'pos': 'ADJ'}, {'text': 'марта', 'tag': 'O', 'pos': 'NOUN'}, {'text': 'прошёл,', 'tag': 'O', 'pos': 'VERB'}, {'text': 'можно', 'tag': 'O', 'pos': 'PUNCT'}, {'text': 'и', 'tag': 'O', 'pos': 'ADV'}, {'text': 'итоги', 'tag': 'O', 'pos': 'PART'}, {'text': 'подвести.', 'tag': 'O', 'pos': 'NOUN'}, {'text': 'Решил', 'tag': 'O', 'pos': 'VERB'}, {'text': 'написать', 'tag': 'O', 'pos': 'PUNCT'}, {'text': 'отзыв', 'tag': 'O', 'pos': 'VERB'}, {'text': 'о', 'tag': 'O', 'pos': 'VERB'}, {'text': 'ресторане', 'tag': 'O', 'pos': 'NOUN'}, {'text': 'в', 'tag': 'O', 'pos': 'ADP'}, {'text': 'котором', 'tag': 'B-Whole', 'pos': 'NOUN'}, {'text': 'отметили', 'tag': 'O', 'pos': 'ADP'}, {'text': 'прекрасный', 'tag': 'O', 'pos': 'PRON'}, {'text': 'весений', 'tag': 'O', 'pos': 'VERB'}, {'text': 'праздник,', 'tag': 'O', 'pos': 'ADJ'}, {'text': 'прочитал', 'tag': 'O', 'pos': 'NOUN'}, {'text': 'отзывы', 'tag': 'O', 'pos': 'NOUN'}, {'text': 'edik077', 'tag': 'O', 'pos': 'PUNCT'}, {'text': 'и', 'tag': 'O', 'pos': 'VERB'}, {'text': 'Rules77777и', 'tag': 'O', 'pos': 'NOUN'}, {'text': 'понял', 'tag': 'O', 'pos': 'PROPN'}, {'text': 'что', 'tag': 'O', 'pos': 'CCONJ'}, {'text': 'либо', 'tag': 'O', 'pos': 'PROPN'}, {'text': 'мы', 'tag': 'O', 'pos': 'VERB'}, {'text': 'были', 'tag': 'O', 'pos': 'SCONJ'}, {'text': 'вразных', 'tag': 'O', 'pos': 'CCONJ'}, {'text': 'ресторанах,', 'tag': 'O', 'pos': 'PRON'}, {'text': 'либо', 'tag': 'O', 'pos': 'AUX'}, {'text': 'у', 'tag': 'O', 'pos': 'ADJ'}, {'text': 'ребят', 'tag': 'B-Whole', 'pos': 'NOUN'}, {'text': 'что-то', 'tag': 'O', 'pos': 'PUNCT'}, {'text': 'незаладилось.', 'tag': 'O', 'pos': 'CCONJ'}, {'text': 'Но', 'tag': 'O', 'pos': 'ADP'}, {'text': 'теперь', 'tag': 'O', 'pos': 'NOUN'}, {'text': 'о', 'tag': 'O', 'pos': 'PRON'}, {'text': 'ресторане.', 'tag': 'O', 'pos': 'VERB'}, {'text': 'Столик', 'tag': 'O', 'pos': 'PUNCT'}, {'text': 'бронировали', 'tag': 'O', 'pos': 'CCONJ'}, {'text': 'заранее', 'tag': 'O', 'pos': 'ADV'}, {'text': 'и', 'tag': 'O', 'pos': 'ADP'}, {'text': 'сделали', 'tag': 'B-Whole', 'pos': 'NOUN'}, {'text': 'так', 'tag': 'O', 'pos': 'PUNCT'}, {'text': 'как', 'tag': 'B-Service', 'pos': 'NOUN'}, {'text': 'предложил', 'tag': 'I-Service', 'pos': 'VERB'}, {'text': 'администратор', 'tag': 'O', 'pos': 'ADV'}, {'text': 'т.е.', 'tag': 'O', 'pos': 'CCONJ'}, {'text': 'сделали', 'tag': 'O', 'pos': 'VERB'}, {'text': 'предварительный', 'tag': 'O', 'pos': 'ADV'}, {'text': 'заказ,', 'tag': 'O', 'pos': 'SCONJ'}, {'text': 'когда', 'tag': 'O', 'pos': 'VERB'}, {'text': 'придя', 'tag': 'B-Service', 'pos': 'NOUN'}, {'text': 'увидели', 'tag': 'O', 'pos': 'PUNCT'}, {'text': 'полностью', 'tag': 'O', 'pos': 'VERB'}, {'text': 'заполненый', 'tag': 'B-Service', 'pos': 'ADJ'}, {'text': 'ресторан', 'tag': 'I-Service', 'pos': 'NOUN'}, {'text': 'поняли', 'tag': 'O', 'pos': 'PUNCT'}, {'text': 'что', 'tag': 'O', 'pos': 'SCONJ'}, {'text': 'совет', 'tag': 'O', 'pos': 'VERB'}, {'text': 'нам', 'tag': 'O', 'pos': 'VERB'}, {'text': 'дали', 'tag': 'O', 'pos': 'ADV'}, {'text': 'действительно', 'tag': 'O', 'pos': 'VERB'}, {'text': 'правильный,', 'tag': 'B-Whole', 'pos': 'NOUN'}, {'text': 'в', 'tag': 'O', 'pos': 'VERB'}, {'text': 'ресторане', 'tag': 'O', 'pos': 'SCONJ'}, {'text': 'было', 'tag': 'O', 'pos': 'NOUN'}, {'text': 'человек', 'tag': 'O', 'pos': 'PRON'}, {'text': '70-80,', 'tag': 'O', 'pos': 'VERB'}, {'text': 'тут', 'tag': 'O', 'pos': 'ADV'}, {'text': 'действительно', 'tag': 'O', 'pos': 'ADJ'}, {'text': 'горячее', 'tag': 'O', 'pos': 'PUNCT'}, {'text': 'блюдо', 'tag': 'O', 'pos': 'ADP'}, {'text': 'можно', 'tag': 'B-Whole', 'pos': 'NOUN'}, {'text': 'ждать', 'tag': 'O', 'pos': 'VERB'}, {'text': 'весьма', 'tag': 'O', 'pos': 'NOUN'}, {'text': 'долго.', 'tag': 'O', 'pos': 'NUM'}, {'text': 'Меню', 'tag': 'O', 'pos': 'PUNCT'}, {'text': 'достаточно', 'tag': 'O', 'pos': 'NUM'}, {'text': 'разнообразное', 'tag': 'O', 'pos': 'PUNCT'}, {'text': 'и', 'tag': 'O', 'pos': 'ADV'},  ...
# ['O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'B-Whole', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'B-Whole', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'B-Whole', 'O', 'B-Service', 'I-Service', 'O', 'O', 'O', 'O', 'O', 'O', 'B-Service', 'O', 'O', 'B-Service', 'I-Service', 'O', 'O', 'O', 'O', 'O', 'O', 'B-Whole', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'B-Whole', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'B-Food', 'I-Food', 'O', 'O', 'O', 'O', 'O', 'B-Food', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'B-Service', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'B-Service', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'B-Interior', 'O', 'O', 'O', 'B-Interior', 'O', 'O', 'O', 'B-Interior', 'I-Interior', 'O', 'O', 'B-Interior']

# %%
X_train = [sent2features(value) for _,value in sents.items()]
y_train = [sent2labels(value) for _,value in sents.items()]

X_test = [sent2features(value) for _,value in sents_test.items()]
y_test = [sent2labels(value) for _,value in sents_test.items()]

# %%
print(len(X_train[0]), len(X_train[1]), len(X_train[2]))
# Out:
# 158 63 98

# %%
crf = sklearn_crfsuite.CRF(
    algorithm='lbfgs', 
    c1=0.1, 
    c2=0.1, 
    max_iterations=100, 
    all_possible_transitions=True
)
crf.fit(X_train, y_train)
# Out:
# /usr/local/lib/python3.7/dist-packages/sklearn/base.py:213: FutureWarning: From version 0.24, get_params will raise an AttributeError if a parameter cannot be retrieved as an instance attribute. Previously it would return None.
#   FutureWarning)
# CRF(algorithm='lbfgs', all_possible_transitions=True, c1=0.1, c2=0.1,
#     keep_tempfiles=None, max_iterations=100)

# %%
labels = list(crf.classes_)
labels.remove('O')
y_pred = crf.predict(X_test)
metrics.flat_f1_score(y_test, y_pred, 
                      average='weighted', labels=labels)
# Out:
# 0.9535563054608727

# %%
sorted_labels = sorted(
    labels, 
    key=lambda name: (name[1:], name[0])
)
print(metrics.flat_classification_report(
    y_test, y_pred, labels=sorted_labels, digits=3
))
# Out:
# /usr/local/lib/python3.7/dist-packages/sklearn/utils/validation.py:70: FutureWarning: Pass labels=['B-Food', 'I-Food', 'B-Interior', 'I-Interior', 'B-Price', 'I-Price', 'B-Service', 'I-Service', 'B-Whole', 'I-Whole'] as keyword args. From version 0.25 passing these as positional arguments will result in an error
#   FutureWarning)
#               precision    recall  f1-score   support
#
#       B-Food      0.978     0.930     0.953       384
#       I-Food      1.000     0.987     0.993       231
#   B-Interior      1.000     0.925     0.961       146
#   I-Interior      1.000     1.000     1.000        27
#      B-Price      1.000     0.958     0.979        24
#      I-Price      1.000     1.000     1.000         6
#    B-Service      0.983     0.836     0.904       281
#    I-Service      0.985     0.970     0.977        67
#      B-Whole      0.966     0.927     0.947       124
#      I-Whole      1.000     0.968     0.984        31
#
#    micro avg      0.986     0.924     0.954      1321
#    macro avg      0.991     0.950     0.970      1321
# weighted avg      0.986     0.924     0.954      1321

# %%
labels = list(crf.classes_)
labels.remove('O')
y_pred = crf.predict(X_test)
metrics.flat_f1_score(y_test, y_pred, 
                      average='weighted', labels=labels)
# Out:
# 0.9535563054608727

# %%
# group B and I results
sorted_labels = sorted(
    labels, 
    key=lambda name: (name[1:], name[0])
)
print(metrics.flat_classification_report(
    y_test, y_pred, labels=sorted_labels, digits=3
))
# Out:
#               precision    recall  f1-score   support
#
#       B-Food      0.978     0.930     0.953       384
#       I-Food      1.000     0.987     0.993       231
#   B-Interior      1.000     0.925     0.961       146
#   I-Interior      1.000     1.000     1.000        27
#      B-Price      1.000     0.958     0.979        24
#      I-Price      1.000     1.000     1.000         6
#    B-Service      0.983     0.836     0.904       281
#    I-Service      0.985     0.970     0.977        67
#      B-Whole      0.966     0.927     0.947       124
#      I-Whole      1.000     0.968     0.984        31
#
#    micro avg      0.986     0.924     0.954      1321
#    macro avg      0.991     0.950     0.970      1321
# weighted avg      0.986     0.924     0.954      1321
# /usr/local/lib/python3.7/dist-packages/sklearn/utils/validation.py:70: FutureWarning: Pass labels=['B-Food', 'I-Food', 'B-Interior', 'I-Interior', 'B-Price', 'I-Price', 'B-Service', 'I-Service', 'B-Whole', 'I-Whole'] as keyword args. From version 0.25 passing these as positional arguments will result in an error
#   FutureWarning)

# %% [markdown]
# ## + Подбор лучших гиперпараметров

# %%
from itertools import chain

import nltk
import sklearn
import scipy.stats
from sklearn.metrics import make_scorer
# from sklearn.cross_validation import cross_val_score
from sklearn.model_selection import RandomizedSearchCV

import sklearn_crfsuite
from sklearn_crfsuite import scorers
from sklearn_crfsuite import metrics

# %%
# %%time
# define fixed parameters and parameters to search
crf = sklearn_crfsuite.CRF(
    algorithm='lbfgs',
    max_iterations=100,
    all_possible_transitions=True
)
params_space = {
    'c1': scipy.stats.expon(scale=0.5),
    'c2': scipy.stats.expon(scale=0.05),
}

# use the same metric for evaluation
f1_scorer = make_scorer(metrics.flat_f1_score,
                        average='weighted', labels=labels)

# search - рандомизированный, чтобы колаб не отвалился
rs = RandomizedSearchCV(crf, params_space,
                        cv=3,
                        verbose=1,
                        n_jobs=-1,
                        n_iter=50,
                        scoring=f1_scorer)
rs.fit(X_train, y_train)
# Out:
# Fitting 3 folds for each of 50 candidates, totalling 150 fits
# /usr/local/lib/python3.7/dist-packages/sklearn/base.py:213: FutureWarning: From version 0.24, get_params will raise an AttributeError if a parameter cannot be retrieved as an instance attribute. Previously it would return None.
#   FutureWarning)
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 2 concurrent workers.
# [Parallel(n_jobs=-1)]: Done  46 tasks      | elapsed:  5.2min
# [Parallel(n_jobs=-1)]: Done 150 out of 150 | elapsed: 16.7min finished
# CPU times: user 11min 44s, sys: 3.29 s, total: 11min 48s
# Wall time: 16min 47s

# %%
print('best params:', rs.best_params_)
print('best CV score:', rs.best_score_)
print('model size: {:0.2f}M'.format(rs.best_estimator_.size_ / 1000000))
# Out:
# best params: {'c1': 0.20060494910360846, 'c2': 0.025813993669070386}
# best CV score: 0.17303120178913833
# model size: 1.10M

# %%
crf = rs.best_estimator_
y_pred = crf.predict(X_test)
print(metrics.flat_classification_report(
    y_test, y_pred, labels=sorted_labels, digits=3
))
# Out:
# /usr/local/lib/python3.7/dist-packages/sklearn/utils/validation.py:70: FutureWarning: Pass labels=['B-Food', 'I-Food', 'B-Interior', 'I-Interior', 'B-Price', 'I-Price', 'B-Service', 'I-Service', 'B-Whole', 'I-Whole'] as keyword args. From version 0.25 passing these as positional arguments will result in an error
#   FutureWarning)
#               precision    recall  f1-score   support
#
#       B-Food      0.979     0.966     0.972       384
#       I-Food      0.996     1.000     0.998       231
#   B-Interior      1.000     0.945     0.972       146
#   I-Interior      1.000     1.000     1.000        27
#      B-Price      1.000     1.000     1.000        24
#      I-Price      1.000     1.000     1.000         6
#    B-Service      0.992     0.900     0.944       281
#    I-Service      1.000     0.970     0.985        67
#      B-Whole      0.975     0.960     0.967       124
#      I-Whole      1.000     0.968     0.984        31
#
#    micro avg      0.989     0.957     0.973      1321
#    macro avg      0.994     0.971     0.982      1321
# weighted avg      0.989     0.957     0.972      1321

# %%
from collections import Counter

def print_transitions(trans_features):
    for (label_from, label_to), weight in trans_features:
        print("%-6s -> %-7s %0.6f" % (label_from, label_to, weight))

print("Top likely transitions:")
print_transitions(Counter(crf.transition_features_).most_common(20))

print("\nTop unlikely transitions:")
print_transitions(Counter(crf.transition_features_).most_common()[-20:])
# Out:
# Top likely transitions:
# I-Price -> I-Price 4.356653
# O      -> O       3.978749
# B-Price -> I-Price 3.819496
# I-Whole -> I-Whole 3.707108
# I-Food -> I-Food  3.604198
# I-Interior -> I-Interior 3.578929
# B-Interior -> I-Interior 3.318069
# B-Service -> I-Service 3.316531
# B-Food -> I-Food  3.253769
# I-Service -> I-Service 2.989325
# B-Whole -> I-Whole 2.565666
# O      -> B-Food  1.716124
# O      -> B-Whole 1.711296
# O      -> B-Service 1.528208
# O      -> B-Interior 1.222927
# O      -> B-Price 1.129034
# I-Service -> O       0.752802
# B-Food -> O       0.638614
# B-Service -> O       0.506112
# I-Interior -> O       0.324695
#
# Top unlikely transitions:
# B-Food -> I-Service -2.764936
# B-Whole -> I-Interior -2.848280
# I-Service -> I-Food  -2.857876
# B-Food -> B-Whole -2.941365
# B-Service -> B-Interior -2.968983
# B-Food -> I-Interior -3.019730
# B-Whole -> B-Service -3.171863
# B-Interior -> I-Food  -3.267092
# B-Food -> I-Whole -3.275526
# B-Service -> I-Food  -3.349889
# B-Food -> B-Interior -3.556431
# B-Whole -> I-Food  -3.611548
# B-Interior -> B-Food  -3.937290
# B-Service -> I-Whole -4.040709
# B-Service -> B-Whole -4.119001
# O      -> I-Price -4.204839
# O      -> I-Interior -5.237393
# O      -> I-Whole -5.491104
# O      -> I-Service -6.239009
# O      -> I-Food  -7.112153

# %% [markdown]
# ## См. также
#
# [python-crfsuite](https://github.com/scrapinghub/python-crfsuite/blob/master/examples/CoNLL%202002.ipynb) - без зависимости от версии scikit-learn
#
# [BERT + CRF for NER](https://github.com/shushanxingzhe/transformers_ner)
